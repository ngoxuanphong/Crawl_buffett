# %%
import pandas as pd

# %%
path = r'A:\Phong\Crawl_buffett\Data'

# %%
pd.read_csv(path+r'\1301\docs\dividend.csv')
# Out:
#     Year Q1 Q2  Q3     Q4  time_split_Q1  time_split_Q2  time_split_Q3
# 0   2022  ―  ―   ―  100.0            NaN            NaN            NaN  \
# 1   2021  ―  ―   ―   90.0            NaN            NaN            NaN
# 2   2020  ―  ―   ―   80.0            NaN            NaN            NaN
# 3   2019  ―  ―   ―   70.0            NaN            NaN            NaN
# 4   2018  ―  ―   ―   70.0            NaN            NaN            NaN
# 5   2017  —  —  ーー   60.0            NaN            NaN            NaN
# 6   2016  —  一   —   60.0            NaN            NaN            NaN
# 7   2015  —  —  ーー    5.0            NaN            NaN            NaN
# 8   2014  ―  ―   ―    5.0            NaN            NaN            NaN
# 9   2013  ―  ―   ―    5.0            NaN            NaN            NaN
# 10  2012  ―  ―   ―    5.0            NaN            NaN            NaN
# 11  2011  ―  ―   ―    5.0            NaN            NaN            NaN
# ...
