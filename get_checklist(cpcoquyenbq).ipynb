# %%
import pandas as pd
import numpy as np
import os

# %%
import pandas as pd
import numpy as np
import time, os
from src.get_volume import get_volume
from src.get_table import get_table
from src.dividend import GetDividend
def get_all_com(reverse: bool = False,
                    bool_get_volume: bool = True,
                    bool_get_dividend: bool = True,
                    bool_get_table: bool = True,):
        """
        Get all company in japan stock
        Parameters
        ----------
        reverse : bool
            reverse list company
        Returns
        -------
        None
        """
        lst_com = pd.read_csv("docs/List_company_23052023 - Listing.csv")
        if "check" not in lst_com.columns:
            lst_com["check"] = np.nan
        if "volume" not in lst_com.columns:
            lst_com["volume"] = np.nan
        if "dividend" not in lst_com.columns:
            lst_com["dividend"] = np.nan
        if "table" not in lst_com.columns:
            lst_com["table"] = np.nan
        lst_com.to_csv("docs/List_company_23052023 - Listing.csv", index=False)
        
        if reverse:
            lst_com = lst_com[::-1]
        for i in lst_com.index:
            id_company = lst_com["Symbol"][i]
            check = lst_com["check"][i]
            if check == "Done":
                error = []
                col = []
                # if bool_get_volume and lst_com["volume"][i] != "Done":
                #     try:
                #         get_volume(id_company, self.path_save, save_file=True)
                #         col.append("volume")
                #     except:
                #         error.append("volume")

                # if bool_get_table and lst_com["table"][i] != "Done":
                #     try:
                #         get_table(id_company, self.path_save, save_file=True)
                #         col.append("table")
                #     except:
                #         error.append("table")

                if bool_get_dividend and lst_com["dividend"][i] != "Done":
                    try:
                        dividendClass = GetDividend(path_save='')
                        dividendClass = get_dividend(id_company, save_file=True)
                        col.append("dividend")
                    except:
                        error.append("dividend")
                    
                lst_com_ = pd.read_csv(self.path_all_com)
                if reverse:
                        lst_com_ = lst_com_[::-1]

                for col_ in col:
                    lst_com_[col_][i] = "Done"
                    if col_ == "dividend":
                        self.save_dividendShares(id_company, "Done")

                for error_ in error:
                    print(f"Error: {id_company}- {error_}")
                    lst_com_[error_][i] = "False"
                    if error_ == "dividend":
                        self.save_dividendShares(id_company, "False")

                lst_com_.sort_index(inplace=True)
                lst_com_.to_csv(self.path_all_com, index=False)

# %%
df = pd.DataFrame(columns = ['Symbol', 'DividendShares']) #DividendShares.csv
for s in os.listdir("Data"):
    if 'dividend.csv' in os.listdir(f"Data/{s}/docs"):
        df.loc[(len(df))] = [s, "Done"]
    else:
        df.loc[(len(df))] = [s, "False"]
df.loc[(len(df))] =['Total', (df['DividendShares']== "Done").sum()]
df.to_csv('docs/DividendShares.csv', index = False)
df
# Out:
#      Symbol DividendShares
# 0      1301          False
# 1      1332          False
# 2      1333          False
# 3      1375          False
# 4      1376          False
# ...     ...            ...
# 1722   9994           Done
# 1723   9995           Done
# 1724   9996           Done
# 1725   9997           Done
# 1726  Total            274
#
# [1727 rows x 2 columns]

# %%
def get_subdirectories(folder_path):
    subdirectories = []
    for item in os.listdir(folder_path):
        item_path = os.path.join(folder_path, item)
        if os.path.isdir(item_path):
            subdirectories.append(item_path)
    return subdirectories

get_subdirectories("Data")
# Out:
# ['Data\\1301',
#  'Data\\1332',
#  'Data\\1333',
#  'Data\\1375',
#  'Data\\1376',
#  'Data\\1377',
#  'Data\\1379',
#  'Data\\1380',
#  'Data\\1381',
#  'Data\\1382',
#  'Data\\1383',
#  'Data\\1384',
#  'Data\\1400',
#  'Data\\1401',
#  'Data\\1407',
#  'Data\\7065',
#  'Data\\7066',
#  'Data\\7067',
#  'Data\\7068',
#  'Data\\7069',
#  'Data\\7071',
#  'Data\\7072',
#  'Data\\7073',
#  'Data\\7074',
#  'Data\\7077',
#  'Data\\7078',
#  'Data\\7079',
#  'Data\\7080',
#  'Data\\7081',
#  'Data\\7082',
#  'Data\\7083',
#  'Data\\7084',
#  'Data\\7085',
#  'Data\\7086',
#  'Data\\7087',
#  'Data\\7088',
#  'Data\\7089',
#  'Data\\7090',
#  'Data\\7091',
#  'Data\\7092',
#  'Data\\7093',
#  'Data\\7094',
#  'Data\\7095',
#  'Data\\7096',
#  'Data\\7097',
#  'Data\\7102',
#  'Data\\7105',
#  'Data\\7110',
#  'Data\\7111',
#  'Data\\7112',
#  'Data\\7114',
#  'Data\\7115',
#  'Data\\7116',
#  'Data\\7119',
#  'Data\\7120',
#  'Data\\7122',
#  'Data\\7126',
#  'Data\\7127',
#  'Data\\7128',
#  'Data\\7129',
#  'Data\\7130',
#  'Data\\7131',
#  'Data\\7133',
#  'Data\\7134',
#  'Data\\7135',
#  'Data\\7138',
#  'Data\\7140',
#  'Data\\7148',
#  'Data\\7150',
#  'Data\\7157',
#  'Data\\7161',
#  'Data\\7162',
#  'Data\\7163',
#  'Data\\7164',
#  'Data\\7167',
#  'Data\\7172',
#  'Data\\7173',
#  'Data\\7175',
#  'Data\\7177',
#  'Data\\7180',
#  'Data\\7181',
#  'Data\\7182',
#  'Data\\7183',
#  'Data\\7184',
#  'Data\\7185',
#  'Data\\7186',
#  'Data\\7187',
#  'Data\\7189',
#  'Data\\7191',
#  'Data\\7192',
#  'Data\\7196',
#  'Data\\7198',
#  'Data\\7199',
#  'Data\\7201',
#  'Data\\7202',
#  'Data\\7203',
#  'Data\\7205',
#  'Data\\7208',
#  'Data\\7211',
#  'Data\\7212',
#  'Data\\7213',
#  'Data\\7214',
#  'Data\\7215',
#  'Data\\7217',
#  'Data\\7218',
#  'Data\\7219',
#  'Data\\7220',
#  'Data\\7222',
#  'Data\\7224',
#  'Data\\7226',
#  'Data\\7228',
#  'Data\\7229',
#  'Data\\7231',
#  'Data\\7235',
#  'Data\\7236',
#  'Data\\7238',
#  'Data\\7239',
#  'Data\\7240',
#  'Data\\7241',
#  'Data\\7242',
#  'Data\\7244',
#  'Data\\7245',
#  'Data\\7246',
#  'Data\\7247',
#  'Data\\7250',
#  'Data\\7254',
#  'Data\\7255',
#  'Data\\7256',
#  'Data\\7259',
#  'Data\\7261',
#  'Data\\7264',
#  'Data\\7265',
#  'Data\\7266',
#  'Data\\7267',
#  'Data\\7268',
#  'Data\\7269',
#  'Data\\7270',
#  'Data\\7271',
#  'Data\\7272',
#  'Data\\7273',
#  'Data\\7276',
#  'Data\\7277',
#  'Data\\7278',
#  'Data\\7279',
#  'Data\\7280',
#  'Data\\7282',
#  'Data\\7283',
#  'Data\\7284',
#  'Data\\7287',
#  'Data\\7291',
#  'Data\\7292',
#  'Data\\7294',
#  'Data\\7296',
#  'Data\\7297',
#  'Data\\7298',
#  'Data\\7299',
#  'Data\\7305',
#  'Data\\7309',
#  'Data\\7313',
#  'Data\\7314',
#  'Data\\7315',
#  'Data\\7317',
#  'Data\\7318',
#  'Data\\7320',
#  'Data\\7322',
#  'Data\\7325',
#  'Data\\7326',
#  'Data\\7327',
#  'Data\\7330',
#  'Data\\7337',
#  'Data\\7338',
#  'Data\\7342',
#  'Data\\7343',
#  'Data\\7345',
#  'Data\\7347',
#  'Data\\7350',
#  'Data\\7351',
#  'Data\\7352',
#  'Data\\7353',
#  'Data\\7354',
#  'Data\\7356',
#  'Data\\7357',
#  'Data\\7358',
#  'Data\\7359',
#  'Data\\7360',
#  'Data\\7361',
#  'Data\\7362',
#  'Data\\7363',
#  'Data\\7366',
#  'Data\\7367',
#  'Data\\7368',
#  'Data\\7369',
#  'Data\\7370',
#  'Data\\7371',
#  'Data\\7372',
#  'Data\\7373',
#  'Data\\7374',
#  'Data\\7375',
#  'Data\\7376',
#  'Data\\7377',
#  'Data\\7378',
#  'Data\\7379',
#  'Data\\7380',
#  'Data\\7381',
#  'Data\\7383',
#  'Data\\7384',
#  'Data\\7386',
#  'Data\\7388',
#  'Data\\7389',
#  'Data\\7399',
#  'Data\\7408',
#  'Data\\7412',
#  'Data\\7413',
#  'Data\\7414',
#  'Data\\7416',
#  'Data\\7417',
#  'Data\\7419',
#  'Data\\7420',
#  'Data\\7421',
#  'Data\\7422',
#  'Data\\7425',
#  'Data\\7426',
#  'Data\\7427',
#  'Data\\7433',
#  'Data\\7434',
#  'Data\\7435',
#  'Data\\7438',
#  'Data\\7442',
#  'Data\\7443',
#  'Data\\7444',
#  'Data\\7445',
#  'Data\\7446',
#  'Data\\7447',
#  'Data\\7450',
#  'Data\\7451',
#  'Data\\7453',
#  'Data\\7455',
#  'Data\\7456',
#  'Data\\7458',
#  'Data\\7459',
#  'Data\\7460',
#  'Data\\7461',
#  'Data\\7462',
#  'Data\\7463',
#  'Data\\7464',
#  'Data\\7466',
#  'Data\\7467',
#  'Data\\7472',
#  'Data\\7475',
#  'Data\\7476',
#  'Data\\7477',
#  'Data\\7480',
#  'Data\\7481',
#  'Data\\7482',
#  'Data\\7483',
#  'Data\\7486',
#  'Data\\7487',
#  'Data\\7490',
#  'Data\\7494',
#  'Data\\7500',
#  'Data\\7501',
#  'Data\\7502',
#  'Data\\7504',
#  'Data\\7505',
#  'Data\\7506',
#  'Data\\7508',
#  'Data\\7509',
#  'Data\\7510',
#  'Data\\7512',
#  'Data\\7513',
#  'Data\\7514',
#  'Data\\7515',
#  'Data\\7516',
#  'Data\\7518',
#  'Data\\7520',
#  'Data\\7521',
#  'Data\\7522',
#  'Data\\7523',
#  'Data\\7524',
#  'Data\\7525',
#  'Data\\7527',
#  'Data\\7531',
#  'Data\\7532',
#  'Data\\7537',
#  'Data\\7538',
#  'Data\\7539',
#  'Data\\7544',
#  'Data\\7545',
#  'Data\\7550',
#  'Data\\7551',
#  'Data\\7552',
#  'Data\\7554',
#  'Data\\7555',
#  'Data\\7559',
#  'Data\\7561',
#  'Data\\7562',
#  'Data\\7564',
#  'Data\\7565',
#  'Data\\7567',
#  'Data\\7570',
#  'Data\\7571',
#  'Data\\7575',
#  'Data\\7578',
#  'Data\\7581',
#  'Data\\7585',
#  'Data\\7590',
#  'Data\\7593',
#  'Data\\7595',
#  'Data\\7596',
#  'Data\\7599',
#  'Data\\7600',
#  'Data\\7601',
#  'Data\\7602',
#  'Data\\7603',
#  'Data\\7604',
#  'Data\\7605',
#  'Data\\7606',
#  'Data\\7607',
#  'Data\\7608',
#  'Data\\7609',
#  'Data\\7610',
#  'Data\\7611',
#  'Data\\7613',
#  'Data\\7614',
#  'Data\\7615',
#  'Data\\7616',
#  'Data\\7618',
#  'Data\\7619',
#  'Data\\7621',
#  'Data\\7623',
#  'Data\\7624',
#  'Data\\7625',
#  'Data\\7628',
#  'Data\\7630',
#  'Data\\7634',
#  'Data\\7635',
#  'Data\\7636',
#  'Data\\7637',
#  'Data\\7638',
#  'Data\\7640',
#  'Data\\7643',
#  'Data\\7646',
#  'Data\\7647',
#  'Data\\7649',
#  'Data\\7670',
#  'Data\\7671',
#  'Data\\7673',
#  'Data\\7674',
#  'Data\\7676',
#  'Data\\7677',
#  'Data\\7678',
#  'Data\\7679',
#  'Data\\7681',
#  'Data\\7682',
#  'Data\\7683',
#  'Data\\7685',
#  'Data\\7686',
#  'Data\\7687',
#  'Data\\7689',
#  'Data\\7692',
#  'Data\\7694',
#  'Data\\7695',
#  'Data\\7698',
#  'Data\\7699',
#  'Data\\7701',
#  'Data\\7702',
#  'Data\\7705',
#  'Data\\7707',
#  'Data\\7709',
#  'Data\\7711',
#  'Data\\7713',
#  'Data\\7715',
#  'Data\\7716',
#  'Data\\7717',
#  'Data\\7718',
#  'Data\\7719',
#  'Data\\7721',
#  'Data\\7722',
#  'Data\\7723',
#  'Data\\7725',
#  'Data\\7726',
#  'Data\\7727',
#  'Data\\7729',
#  'Data\\7730',
#  'Data\\7731',
#  'Data\\7732',
#  'Data\\7733',
#  'Data\\7734',
#  'Data\\7735',
#  'Data\\7739',
#  'Data\\7740',
#  'Data\\7741',
#  'Data\\7743',
#  'Data\\7744',
#  'Data\\7745',
#  'Data\\7746',
#  'Data\\7747',
#  'Data\\7749',
#  'Data\\7751',
#  'Data\\7752',
#  'Data\\7760',
#  'Data\\7762',
#  'Data\\7769',
#  'Data\\7771',
#  'Data\\7774',
#  'Data\\7775',
#  'Data\\7776',
#  'Data\\7777',
#  'Data\\7779',
#  'Data\\7780',
#  'Data\\7781',
#  'Data\\7782',
#  'Data\\7791',
#  'Data\\7792',
#  'Data\\7793',
#  'Data\\7794',
#  'Data\\7795',
#  'Data\\7800',
#  'Data\\7803',
#  'Data\\7804',
#  'Data\\7805',
#  'Data\\7806',
#  'Data\\7807',
#  'Data\\7808',
#  'Data\\7809',
#  'Data\\7810',
#  'Data\\7811',
#  'Data\\7812',
#  'Data\\7813',
#  'Data\\7814',
#  'Data\\7815',
#  'Data\\7816',
#  'Data\\7817',
#  'Data\\7818',
#  'Data\\7819',
#  'Data\\7820',
#  'Data\\7821',
#  'Data\\7822',
#  'Data\\7823',
#  'Data\\7826',
#  'Data\\7827',
#  'Data\\7829',
#  'Data\\7831',
#  'Data\\7832',
#  'Data\\7833',
#  'Data\\7836',
#  'Data\\7837',
#  'Data\\7839',
#  'Data\\7840',
#  'Data\\7841',
#  'Data\\7844',
#  'Data\\7846',
#  'Data\\7847',
#  'Data\\7849',
#  'Data\\7850',
#  'Data\\7851',
#  'Data\\7856',
#  'Data\\7857',
#  'Data\\7859',
#  'Data\\7860',
#  'Data\\7863',
#  'Data\\7864',
#  'Data\\7865',
#  'Data\\7867',
#  'Data\\7868',
#  'Data\\7871',
#  'Data\\7872',
#  'Data\\7874',
#  'Data\\7875',
#  'Data\\7877',
#  'Data\\7878',
#  'Data\\7879',
#  'Data\\7883',
#  'Data\\7885',
#  'Data\\7886',
#  'Data\\7887',
#  'Data\\7888',
#  'Data\\7893',
#  'Data\\7896',
#  'Data\\7897',
#  'Data\\7898',
#  'Data\\7899',
#  'Data\\7901',
#  'Data\\7902',
#  'Data\\7905',
#  'Data\\7906',
#  'Data\\7908',
#  'Data\\7911',
#  'Data\\7912',
#  'Data\\7914',
#  'Data\\7915',
#  'Data\\7916',
#  'Data\\7917',
#  'Data\\7918',
#  'Data\\7919',
#  'Data\\7921',
#  'Data\\7922',
#  'Data\\7923',
#  'Data\\7925',
#  'Data\\7927',
#  'Data\\7928',
#  'Data\\7931',
#  'Data\\7932',
#  'Data\\7936',
#  'Data\\7937',
#  'Data\\7938',
#  'Data\\7939',
#  'Data\\7940',
#  'Data\\7942',
#  'Data\\7943',
#  'Data\\7944',
#  'Data\\7946',
#  'Data\\7947',
#  'Data\\7949',
#  'Data\\7951',
#  'Data\\7952',
#  'Data\\7953',
#  'Data\\7955',
#  'Data\\7956',
#  'Data\\7957',
#  'Data\\7958',
#  'Data\\7961',
#  'Data\\7962',
#  'Data\\7963',
#  'Data\\7965',
#  'Data\\7966',
#  'Data\\7970',
#  'Data\\7971',
#  'Data\\7972',
#  'Data\\7974',
#  'Data\\7975',
#  'Data\\7976',
#  'Data\\7979',
#  'Data\\7980',
#  'Data\\7981',
#  'Data\\7983',
#  'Data\\7984',
#  'Data\\7985',
#  'Data\\7986',
#  'Data\\7987',
#  'Data\\7988',
#  'Data\\7989',
#  'Data\\7990',
#  'Data\\7991',
#  'Data\\7992',
#  'Data\\7994',
#  'Data\\7995',
#  'Data\\7997',
#  'Data\\7999',
#  'Data\\8001',
#  'Data\\8002',
#  'Data\\8005',
#  'Data\\8006',
#  'Data\\8007',
#  'Data\\8008',
#  'Data\\8011',
#  'Data\\8012',
#  'Data\\8013',
#  'Data\\8014',
#  'Data\\8015',
#  'Data\\8016',
#  'Data\\8018',
#  'Data\\8020',
#  'Data\\8022',
#  'Data\\8023',
#  'Data\\8025',
#  'Data\\8029',
#  'Data\\8030',
#  'Data\\8031',
#  'Data\\8032',
#  'Data\\8035',
#  'Data\\8037',
#  'Data\\8038',
#  'Data\\8039',
#  'Data\\8040',
#  'Data\\8041',
#  'Data\\8043',
#  'Data\\8045',
#  'Data\\8046',
#  'Data\\8050',
#  'Data\\8051',
#  'Data\\8052',
#  'Data\\8053',
#  'Data\\8056',
#  'Data\\8057',
#  'Data\\8058',
#  'Data\\8059',
#  'Data\\8060',
#  'Data\\8061',
#  'Data\\8065',
#  'Data\\8066',
#  'Data\\8068',
#  'Data\\8070',
#  'Data\\8072',
#  'Data\\8074',
#  'Data\\8075',
#  'Data\\8076',
#  'Data\\8077',
#  'Data\\8078',
#  'Data\\8079',
#  'Data\\8081',
#  'Data\\8084',
#  'Data\\8085',
#  'Data\\8086',
#  'Data\\8088',
#  'Data\\8089',
#  'Data\\8091',
#  'Data\\8093',
#  'Data\\8095',
#  'Data\\8097',
#  'Data\\8098',
#  'Data\\8101',
#  'Data\\8103',
#  'Data\\8104',
#  'Data\\8105',
#  'Data\\8107',
#  'Data\\8111',
#  'Data\\8113',
#  'Data\\8114',
#  'Data\\8115',
#  'Data\\8117',
#  'Data\\8118',
#  'Data\\8119',
#  'Data\\8123',
#  'Data\\8125',
#  'Data\\8127',
#  'Data\\8129',
#  'Data\\8130',
#  'Data\\8131',
#  'Data\\8132',
#  'Data\\8133',
#  'Data\\8135',
#  'Data\\8136',
#  'Data\\8137',
#  'Data\\8138',
#  'Data\\8139',
#  'Data\\8140',
#  'Data\\8141',
#  'Data\\8142',
#  'Data\\8143',
#  'Data\\8144',
#  'Data\\8147',
#  'Data\\8150',
#  'Data\\8151',
#  'Data\\8152',
#  'Data\\8153',
#  'Data\\8154',
#  'Data\\8155',
#  'Data\\8157',
#  'Data\\8158',
#  'Data\\8159',
#  'Data\\8160',
#  'Data\\8163',
#  'Data\\8165',
#  'Data\\8166',
#  'Data\\8167',
#  'Data\\8168',
#  'Data\\8173',
#  'Data\\8174',
#  'Data\\8179',
#  'Data\\8181',
#  'Data\\8182',
#  'Data\\8185',
#  'Data\\8194',
#  'Data\\8198',
#  'Data\\8200',
#  'Data\\8202',
#  'Data\\8203',
#  'Data\\8207',
#  'Data\\8208',
#  'Data\\8209',
#  'Data\\8214',
#  'Data\\8215',
#  'Data\\8217',
#  'Data\\8218',
#  'Data\\8219',
#  'Data\\8225',
#  'Data\\8226',
#  'Data\\8227',
#  'Data\\8230',
#  'Data\\8233',
#  'Data\\8237',
#  'Data\\8242',
#  'Data\\8244',
#  'Data\\8247',
#  'Data\\8252',
#  'Data\\8253',
#  'Data\\8254',
#  'Data\\8255',
#  'Data\\8256',
#  'Data\\8260',
#  'Data\\8267',
#  'Data\\8273',
#  'Data\\8275',
#  'Data\\8276',
#  'Data\\8278',
#  'Data\\8279',
#  'Data\\8281',
#  'Data\\8282',
#  'Data\\8283',
#  'Data\\8285',
#  'Data\\8289',
#  'Data\\8291',
#  'Data\\8301',
#  'Data\\8303',
#  'Data\\8304',
#  'Data\\8306',
#  'Data\\8308',
#  'Data\\8309',
#  'Data\\8316',
#  'Data\\8331',
#  'Data\\8334',
#  'Data\\8336',
#  'Data\\8337',
#  'Data\\8338',
#  'Data\\8341',
#  'Data\\8343',
#  'Data\\8344',
#  'Data\\8345',
#  'Data\\8346',
#  'Data\\8349',
#  'Data\\8354',
#  'Data\\8358',
#  'Data\\8359',
#  'Data\\8360',
#  'Data\\8361',
#  'Data\\8362',
#  'Data\\8364',
#  'Data\\8365',
#  'Data\\8366',
#  'Data\\8367',
#  'Data\\8368',
#  'Data\\8369',
#  'Data\\8370',
#  'Data\\8377',
#  'Data\\8381',
#  'Data\\8383',
#  'Data\\8386',
#  'Data\\8387',
#  'Data\\8388',
#  'Data\\8392',
#  'Data\\8393',
#  'Data\\8395',
#  'Data\\8399',
#  'Data\\8410',
#  'Data\\8411',
#  'Data\\8416',
#  'Data\\8418',
#  'Data\\8421',
#  'Data\\8424',
#  'Data\\8425',
#  'Data\\8439',
#  'Data\\8462',
#  'Data\\8473',
#  'Data\\8508',
#  'Data\\8511',
#  'Data\\8515',
#  'Data\\8518',
#  'Data\\8521',
#  'Data\\8522',
#  'Data\\8524',
#  'Data\\8537',
#  'Data\\8541',
#  'Data\\8542',
#  'Data\\8544',
#  'Data\\8550',
#  'Data\\8551',
#  'Data\\8558',
#  'Data\\8562',
#  'Data\\8563',
#  'Data\\8566',
#  'Data\\8570',
#  'Data\\8572',
#  'Data\\8584',
#  'Data\\8585',
#  'Data\\8591',
#  'Data\\8593',
#  'Data\\8595',
#  'Data\\8596',
#  'Data\\8600',
#  'Data\\8601',
#  'Data\\8604',
#  'Data\\8609',
#  'Data\\8613',
#  'Data\\8614',
#  'Data\\8616',
#  'Data\\8617',
#  'Data\\8622',
#  'Data\\8624',
#  'Data\\8628',
#  'Data\\8630',
#  'Data\\8697',
#  'Data\\8698',
#  'Data\\8699',
#  'Data\\8700',
#  'Data\\8704',
#  'Data\\8705',
#  'Data\\8706',
#  'Data\\8707',
#  'Data\\8708',
#  'Data\\8713',
#  'Data\\8714',
#  'Data\\8715',
#  'Data\\8725',
#  'Data\\8732',
#  'Data\\8737',
#  'Data\\8739',
#  'Data\\8742',
#  'Data\\8746',
#  'Data\\8747',
#  'Data\\8750',
#  'Data\\8766',
#  'Data\\8769',
#  'Data\\8771',
#  'Data\\8772',
#  'Data\\8783',
#  'Data\\8789',
#  'Data\\8793',
#  'Data\\8795',
#  'Data\\8798',
#  'Data\\8801',
#  'Data\\8802',
#  'Data\\8803',
#  'Data\\8804',
#  'Data\\8818',
#  'Data\\8830',
#  'Data\\8835',
#  'Data\\8836',
#  'Data\\8841',
#  'Data\\8842',
#  'Data\\8844',
#  'Data\\8848',
#  'Data\\8850',
#  'Data\\8854',
#  'Data\\8860',
#  'Data\\8864',
#  'Data\\8869',
#  'Data\\8871',
#  'Data\\8876',
#  'Data\\8877',
#  'Data\\8881',
#  'Data\\8886',
#  'Data\\8887',
#  'Data\\8889',
#  'Data\\8890',
#  'Data\\8891',
#  'Data\\8892',
#  'Data\\8893',
#  'Data\\8894',
#  'Data\\8897',
#  'Data\\8898',
#  'Data\\8903',
#  'Data\\8904',
#  'Data\\8905',
#  'Data\\8908',
#  'Data\\8912',
#  'Data\\8914',
#  'Data\\8917',
#  'Data\\8918',
#  'Data\\8919',
#  'Data\\8920',
#  'Data\\8923',
#  'Data\\8925',
#  'Data\\8927',
#  'Data\\8928',
#  'Data\\8929',
#  'Data\\8931',
#  'Data\\8934',
#  'Data\\8935',
#  'Data\\8938',
#  'Data\\8940',
#  'Data\\8944',
#  'Data\\8945',
#  'Data\\8946',
#  'Data\\8995',
#  'Data\\8996',
#  'Data\\8999',
#  'Data\\9001',
#  'Data\\9003',
#  'Data\\9005',
#  'Data\\9006',
#  'Data\\9007',
#  'Data\\9008',
#  'Data\\9009',
#  'Data\\9010',
#  'Data\\9012',
#  'Data\\9017',
#  'Data\\9020',
#  'Data\\9021',
#  'Data\\9022',
#  'Data\\9024',
#  'Data\\9025',
#  'Data\\9028',
#  'Data\\9029',
#  'Data\\9031',
#  'Data\\9033',
#  'Data\\9034',
#  'Data\\9036',
#  'Data\\9037',
#  'Data\\9039',
#  'Data\\9041',
#  'Data\\9042',
#  'Data\\9044',
#  'Data\\9045',
#  'Data\\9046',
#  'Data\\9048',
#  'Data\\9049',
#  'Data\\9051',
#  'Data\\9052',
#  'Data\\9055',
#  'Data\\9057',
#  'Data\\9058',
#  'Data\\9059',
#  'Data\\9060',
#  'Data\\9063',
#  'Data\\9064',
#  'Data\\9065',
#  'Data\\9066',
#  'Data\\9067',
#  'Data\\9068',
#  'Data\\9069',
#  'Data\\9070',
#  'Data\\9072',
#  'Data\\9073',
#  'Data\\9074',
#  'Data\\9075',
#  'Data\\9076',
#  'Data\\9078',
#  'Data\\9081',
#  'Data\\9082',
#  'Data\\9083',
#  'Data\\9087',
#  'Data\\9090',
#  'Data\\9099',
#  'Data\\9101',
#  'Data\\9104',
#  'Data\\9107',
#  'Data\\9110',
#  'Data\\9115',
#  'Data\\9119',
#  'Data\\9127',
#  'Data\\9130',
#  'Data\\9142',
#  'Data\\9143',
#  'Data\\9145',
#  'Data\\9147',
#  'Data\\9171',
#  'Data\\9173',
#  'Data\\9193',
#  'Data\\9201',
#  'Data\\9202',
#  'Data\\9204',
#  'Data\\9206',
#  'Data\\9211',
#  'Data\\9212',
#  'Data\\9213',
#  'Data\\9214',
#  'Data\\9215',
#  'Data\\9216',
#  'Data\\9218',
#  'Data\\9219',
#  'Data\\9220',
#  'Data\\9221',
#  'Data\\9227',
#  'Data\\9229',
#  'Data\\9232',
#  'Data\\9233',
#  'Data\\9240',
#  'Data\\9241',
#  'Data\\9242',
#  'Data\\9244',
#  'Data\\9245',
#  'Data\\9246',
#  'Data\\9247',
#  'Data\\9248',
#  'Data\\9249',
#  'Data\\9250',
#  'Data\\9251',
#  'Data\\9252',
#  'Data\\9253',
#  'Data\\9254',
#  'Data\\9256',
#  'Data\\9257',
#  'Data\\9258',
#  'Data\\9259',
#  'Data\\9260',
#  'Data\\9262',
#  'Data\\9263',
#  'Data\\9264',
#  'Data\\9265',
#  'Data\\9267',
#  'Data\\9268',
#  'Data\\9270',
#  'Data\\9271',
#  'Data\\9272',
#  'Data\\9273',
#  'Data\\9274',
#  'Data\\9275',
#  'Data\\9278',
#  'Data\\9279',
#  ...]
