# %%
from get_table import *
pd.options.display.max_rows = 9999

# %%
pd.read_csv('tests/Data/1333/docs/pl/2020_Q2.csv')
# Out:
#                  百万円  前第２四半期連結累計期間 当第２四半期連結累計期間
# 0                売上高       447,007      415,776
# 1               売上原価       386,420      355,795
# 2              売上総利益        60,587       59,980
# 3         販売費及び一般管理費        50,690       49,590
# 4               営業利益         9,896       10,390
# 5              営業外収益           NaN          NaN
# 6              受取配当金           649          579
# 7                雑収入         2,058        2,197
# 8            営業外収益合計         2,708        2,777
# 9              営業外費用           NaN          NaN
# 10              支払利息           845          762
# 11               雑支出           262          416
# 12           営業外費用合計         1,107        1,179
# 13              経常利益        11,496       11,987
# 14              特別利益           NaN          NaN
# 15             受取賠償金         1,940            －
# 16           固定資産売却益           181           12
# 17               その他           465            －
# 18            特別利益合計         2,587           12
# ...

# %%
path_file = "tests/Data/1375/PDF/2021_Q3_決算短信(2022_2_3).pdf"
pdf = pdfplumber.open(path_file)
page = pdf.pages[6]
text = page.extract_text()
text
# if text.find('負債の部') != -1:
#     table_text = text[text.find('負債の部'):]
# table_text
# text1 = text[: text.find('利益')]
# text1
# text[ text1.rfind('\n') + 1: ]
# convert_text_table(text[text.find('資産の部'):], 3)
# tables = page.extract_tables()
# tables
# df = extract_pdf(path_file, 'pl')
# df
# Out:
# '株式会社雪国まいたけ（1375）\n2022年３月期 第３四半期決算短信\n２．要約四半期連結財務諸表及び主な注記\n（１）要約四半期連結財政状態計算書\n（単位：百万円）\n前連結会計年度末 当第３四半期連結会計期間末\n（2021年３月31日） （2021年12月31日）\n資産\n流動資産\n現金及び現金同等物 3,777 2,793\n営業債権及びその他の債権 2,021 3,456\n棚卸資産 1,390 1,443\n生物資産 2,904 3,962\nその他の資産 108 96\n流動資産合計 10,202 11,751\n非流動資産\n有形固定資産 18,031 18,948\n投資不動産 316 97\nのれん及び無形資産 5,304 5,297\n使用権資産 461 360\n退職給付に係る資産 450 438\nその他の金融資産 146 163\n繰延税金資産 638 652\nその他の資産 92 67\n非流動資産合計 25,441 26,025\n資産合計 35,644 37,776\n- 5 -'

# %%
extract_data_pdf_pl(pdf,
                     lst_table = [],
                     page_id = 15,
                     type_data = 'avoid_keyword',
                     lst_str = pl_text)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 extract_data_pdf_pl(pdf,
#       2                      lst_table = [],
#       3                      page_id = 15,
#       4                      type_data = 'avoid_keyword',
#       5                      lst_str = pl_text)
#
# File c:\Users\admin\Crawl_buffett\get_table.py:167, in extract_data_pdf_pl(pdf, lst_table, page_id, type_data, lst_str)
#     165 # Tìm số cột
#     166 COUNT_ = 10
# --> 167 for str in table_text.split('\n')[:-1]: # kiểm tra 10 dòng đầu để xem cần bao nhiêu cột
#     168     COUNT_ -= 1
#     169     row_ = str.split(' ')
#
# UnboundLocalError: local variable 'table_text' referenced before assignment

# %%
# get_table(1376, type_ = 'bs',
#                path_save = 'tests/',
#                return_df = True,
#                save_file = False)
