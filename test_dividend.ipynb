# %%
import pandas as pd
from dividend.get_dividend import *
pd.options.display.max_rows = 9999

# %%
get_data_from_pdf(1301, 2022, 'Q3', path_save = 'tests/')
# Out:
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# The output file size is 8.84× larger than the input file.
# Possible reasons for this include:
# --force-ocr was issued, causing transcoding.
# Optimization was disabled.
# '_'

# %%
import pandas as pd

df = pd.read_csv('/Users/mac/Monthy/Crawl_buffett/docs/List_company_23052023 - Listing.csv')

# %%
df[::-1].sort_index()
# Out:
#       Symbol check
# 0       1301  Done
# 1       1332  Done
# 2       1333  Done
# 3       1375  Done
# 4       1376  Done
# ...      ...   ...
# 3805    9993   NaN
# 3806    9994   NaN
# 3807    9995   NaN
# 3808    9996   NaN
# 3809    9997   NaN
#
# [3810 rows x 2 columns]

# %%
id_company = 1301
file_name = '2022_Q3_決算短信(2023_2_3).pdf'
path_save = 'tests/'
text = convert_pdf_to_text(path_save + f'Data/{id_company}/PDF/{file_name}')
ocr_pdf(path_save + f'Data/{id_company}/PDF/{file_name}')
text_ = convert_pdf_to_text('tests/ocr.pdf')
# Out:
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# The output file size is 8.84× larger than the input file.
# Possible reasons for this include:
# --force-ocr was issued, causing transcoding.
# Optimization was disabled.

# %%
text = text_.replace(" ", "")
text
# Out:
# '2023年3月期第3四半期決算短信日本基準」BR)\n上場会社名株式会社極洋\nコード番号1301URLhttos;//www.kyokuyo.co.p\n代表者役職名)代表取締役社長氏名)井上ih\n問合せ先責任者役職名)常務取締役経営管理部長氏名)槽垣仁志\n四半期報告書提出予定日\n配当支払開始予定日2023年2月7日\n四半期決算補足説明資料作成の有無無\n四半期決算説明会開催の有無無\n1.2023年3月期第3四半期の連結業績%022年4月1日-2022年12月31日)\n)連結経営成績Rat)上場取引所2023年2月3日\n東\nTEL03-9545-0703\n自万円未満切捨て)\n⑯表示は、対前年同四半期増減率)\nーーレヒanhale親会社株主に帰属する\n百万円%百万円%百万円%百万円%\n2023年3月期第3四半期213.36/6.48,12442.28,33938.35964494\n2022年3月期第3四半期200.4//3.1571555.26,0305183,99123.9\n往)包括利益2023年3月期第3四半期5852百万円979%)2022年3月期第3四半期2956百万円ムA53.99%)\nww潜在株式調整後styし中#\nVRS1Pei1株当たり半期純利益円銭円銭\n2023年3月期第3四半期5558/ーー\n2022年3月期第3四半期3/1.07ーー\n2)連結財政状態\n総資産fiSE自己資本比率\n百万円百万円%\n2023年3月期第3四半期166,09546,90228.6\n2022年3月期130,46042,17432.1\n参考)自己資本2023年3月期第3四半期47.466百万円2022年3月期42.705百万円\n2.配当の状況\n年間配当金\n第1四半期末第2四半期末第3四半期末期末合計円銭円銭円銭円銭円銭\n2022年3月期ーーーーーー90.0090.00\n2023年3月期ーーーーーー\n2023年3月期7)90.0090.00\n往)直近に公表されている配当予想からの修正の有無:無\n3.2023年3月期の連結業績予想202244月1日-202343月31日)\n⑯表示は、対前期増減率)\nーーレヒanhale親会社株主に帰属する|1株当たりvit=|HE|\nalia=RAStieFs当期純利
# ...

# %%
text[text.find('四半期報告書提出予定日') + 11] == '\n'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 text[text.find('四半期報告書提出予定日') + 11] == '\n'
#
# NameError: name 'text' is not defined

# %%
df = get_dividend(1332, 'tests/', True, False)
df
# Out:
# page has no images - all vector content will be rasterized at 400 DPI, losing some resolution and likely increasing file size. Use --oversample to adjust the DPI.
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# The output file size is 3.14× larger than the input file.
# Possible reasons for this include:
# --force-ocr was issued, causing transcoding.
# Optimization was disabled.
#
# page has no images - all vector content will be rasterized at 400 DPI, losing some resolution and likely increasing file size. Use --oversample to adjust the DPI.
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# The output file size is 1.39× larger than the input file.
# Possible reasons for this include:
# --force-ocr was issued, causing transcoding.
# Optimization was disabled.
#
# [tesseract] lots of diacritics - possibly poor OCR
# ...

# %%
df
# Out:
#        time      time2
# 0   2022_Q1
# 1   2021_Q1
# 2   2020_Q1
# 3   2019_Q1
# 4   2018_Q1
# 5   2017_Q1
# 6   2016_Q1
# 7   2015_Q1
# 8   2014_Q1
# 9   2013_Q1        N/A
# 10  2022_Q2
# 11  2021_Q2
# 12  2020_Q2
# 13  2019_Q2
# 14  2018_Q2
# 15  2017_Q2
# 16  2016_Q2
# 17  2015_Q2
# 18  2014_Q2
# 19  2013_Q2        N/A
# 20  2022_Q3
# 21  2021_Q3
# 22  2020_Q3
# 23  2019_Q3
# 24  2018_Q3
# 25  2017_Q3
# 26  2016_Q3
# 27  2015_Q3
# 28  2014_Q3
# 29  2013_Q3        N/A
# 30  2022_Q4  28_6_2023
# 31  2021_Q4  29_6_2022
# 32  2020_Q4  25_6_2021
# 33  2019_Q4  26_6_2020
# 34  2018_Q4  27_6_2019
# 35  2017_Q4  28_6_2018
# 36  2016_Q4  29_6_2017
# 37  2015_Q4  29_6_2016
# 38  2014_Q4  26_6_2015
# 39  2013_Q4        N/A

# %%
ocr_pdf('tests/Data/1332/PDF/2017_Q2_決算短信(2017_11_2).pdf')
text_ = convert_pdf_to_text('tests/ocr.pdf')
# Out:
# page has no images - all vector content will be rasterized at 400 DPI, losing some resolution and likely increasing file size. Use --oversample to adjust the DPI.
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# The output file size is 1.44× larger than the input file.
# Possible reasons for this include:
# --force-ocr was issued, causing transcoding.
# Optimization was disabled.

# %%
text_ = text_.replace(' ', '')
# text_
idx = text_.find('TEL')#配当支払開始予定日
time_text = text_[idx + 16: + idx + 27]
if time_text[0: 2] =='平成' or time_text[0: 2] == '20':
    matches = re.findall(r'\d+', time_text)
    if len(matches) == 3 :
        if int(matches[0]) > 2000:
            print( [f'{int(matches[2])}_{int(matches[1])}_{int(matches[0])}'])
        else:
            print( [f'{int(matches[2])}_{int(matches[1])}_{int(matches[0]) + 1988 }'])
    print('   -  ')
# Out:
# ['4_12_2017']
#    -
