# %%
# %cd ..
# Out:
# c:\Users\admin\Crawl_buffett

# %%
from src.get_table import *
dividendClass = GetTable(path_save='tests/')
# id_company = 9888
# dividendClass.getTable(id_company= id_company,
#                      return_df=False, 
#                      save_file= True)

# %%
for file in os.listdir('tests/' + f"Data"):
    id_company = int(file)
    dividendClass.getTable(id_company= id_company,
                     return_df=False, 
                     save_file= True)
# Out:
# Get table of 1301
# Get table of 1332
# Get table of 1333
# Get table of 1375
# Get table of 1376
# Get table of 9636
# Get table of 9672
# Get table of 9831
# Get table of 9873
# Get table of 9888
# Get table of 9994
# Get table of 9995
# Get table of 9996
# Get table of 9997

# %%
pd.options.display.max_rows = 9999

# %%
pd.read_csv("tests/Data/9888/docs/checklist_get_table.csv")

# %%
import pdfplumber
import os
import re
import pandas as pd
import numpy as np

pl_text = [
    "四半期連結損益及び包括利益計算書",
    "四半期連結損益計算書",
    "四半期連結損益及び包括利益計算書",
    "連結損益及び包括利益計算書",
    "連結損益計算書",
    '損益計算書'
]

bs_text = ["四半期連結貸借対照表", "連結貸借対照表", "連結財政状態計算書", '貸借対照表'] 


def find_header(pdf, page_id: int, n_cols=3):
    page = pdf.pages[page_id]
    text = page.extract_text()
    DON_VI = "単位"

    idx_dv = text.find(DON_VI)
    if idx_dv >= 0:
        text1 = text[idx_dv:]
        ## Tim don vi
        Yen_unit = text1[3 : text1.find("\n") - 1]
        ## Tim field
        text2 = text1[text1.find("\n") + 1 :]
        text3 = text2[: text2.find("\n")]
        text3 = text3.split(" ")

        if len(text3) != n_cols - 1:
            return [Yen_unit] + ["B"] * (n_cols - 1)
        return [Yen_unit] + text3

    else:
        return ["N/A"] * n_cols


def check_str(text, lst_str):
    for s in lst_str:
        idx = text.find(s)
        if idx != -1:
            return idx < text.find("単位")
    return False


def convert_text_table(text, n_cols=3):
    lst_rows = text.split("\n")
    lst_table = []
    for r in lst_rows:
        row_ = r.split(" ")
        row = []
        for s in row_:
            if "※" not in s:
                row += [s]

        if len(row) < n_cols:
            row += [None] * (n_cols - len(row))
        elif len(row) > n_cols:
            row = [None] * n_cols
        lst_table += [row]
    return lst_table


def extract_data_pdf_bs(
    pdf, lst_table=[], page_id=0, type_data="find_keyword", lst_str=[]
):
    page = pdf.pages[page_id]
    text = page.extract_text()
    text_ = text.replace(" ", "")

    if type_data == "find_keyword":
        find_key = check_str(text_, lst_str)
    if type_data == "avoid_keyword":
        try:
            if int(text_[1]) == 2:
                find_key = False
            else:
                find_key = True
        except:
            idx = text_.find("\n")
            try:
                if int(text_[idx + 2]) == 2:
                    find_key = False
                else:
                    find_key = True
            except:
                find_key = True

        # find_key = False
        # if text_[1: 3] == '単位':
        #     find_key = True
        # idx = text_.find('\n')
        # if text_[idx + 2: idx + 4] == '単位':
        #     find_key = True

    n_cols = 0
    if find_key == True:
        table_text = ""
        if type_data == "find_keyword":
            table_text = text[text.find("資産の部") :]
        if type_data == "avoid_keyword":
            if text.find("負債の部") != -1:
                table_text = text[text.find("負債の部") :]
            elif text.find("資産の部") != -1:
                table_text = text[text.find("資産の部") :]

        # Tìm số cột
        if table_text.count('\n') > 5: #bảng đủ ngắn chứng tỏ bị lỗi
            COUNT_ = 10
            for str in table_text.split("\n")[:-1]:  # find count columns by 10 first rows
                COUNT_ -= 1
                row_ = str.split(" ")
                row = []
                for s in row_:
                    if "※" not in s:
                        row += [s]

                n_cols = max(n_cols, len(row))
                if COUNT_ == 0:
                    break

            # find table
            if n_cols > 5:
                return 10/0 ### tạo ra bug để báo lỗi khi số cột sai >5
            lst_table += convert_text_table(table_text, n_cols)
            return lst_table, n_cols, True
    return lst_table, n_cols, False


def extract_data_pdf_pl(
    pdf, lst_table=[], page_id=0, type_data="find_keyword", lst_str=[]
):
    page = pdf.pages[page_id]
    text = page.extract_text()
    text_ = text.replace(" ", "")

    if type_data == "find_keyword":
        find_key = check_str(text_, lst_str)
    if type_data == "avoid_keyword":
        try:
            if int(text_[1]) : # vị trí này là số (thường là 3)
                find_key = False
            else:
                find_key = True
        except:
            idx = text_.find("\n")
            try:
                if int(text_[idx + 2]): #vị trí này là số (thường là 3)
                    find_key = False
                else:
                    find_key = True
            except:
                find_key = True

    n_cols = 0

    if find_key == True:
        table_text = ""
        if text.find("売上高") != -1 and type_data == "find_keyword":
            # print(text.find("売上高"))
            table_text = text[text.find("売上高") :]
        else:
            for str_key in ["四半期純利益", '営業外費用', "当期純利益", "特別利益", "その他の包括利益"]:
                if text.find(str_key) != -1:
                    text1 = text[: text.find(str_key)]
                    table_text = text[text1.rfind("\n") + 1 :]
                    break
        
        # Tìm số cột
        COUNT_ = 5
        # print(table_text)
        if table_text.count('\n') > 5:
            for str in table_text.split("\n")[:-1]:  # không tính phần ghi số trang
                COUNT_ -= 1
                row_ = str.split(" ")
                row = []
                for s in row_:
                    if "※" not in s:
                        row += [s]

                n_cols = max(n_cols, len(row))
                if COUNT_ == 0:
                    break

            # find table
            if n_cols > 5:
                return 10/0 ### tạo ra bug để báo lỗi khi số cột sai >5
            lst_table += convert_text_table(table_text, n_cols)
            return lst_table, n_cols, True
    return lst_table, n_cols, False


def extract_pdf(path_file, type_):
    pdf = pdfplumber.open(path_file)
    if type_ == "bs":
        key = bs_text
        for page_id in range(len(pdf.pages)):
            lst_table, n_cols, _ = extract_data_pdf_bs(
                pdf,
                lst_table=[],
                page_id=page_id,
                type_data="find_keyword",
                lst_str=key,
            )
            if _ == True:
                lst_col = find_header(pdf, page_id=page_id, n_cols=n_cols)
                break
        
        while True:
            # print(page_id)
            lst_table, n_cols, _ = extract_data_pdf_bs(
                pdf,
                lst_table=lst_table,
                page_id=page_id + 1,
                type_data="avoid_keyword",
                lst_str=[],
            )
            if _ == True:
                page_id += 1
            else:
                break
        # print(lst_table)
        # print(lst_col)
        df = pd.DataFrame(lst_table, columns=lst_col)
        # df[df[df.columns[0]] != '―']
        return df.replace("", None)

    if type_ == "pl":
        key = pl_text
        for page_id in range(len(pdf.pages)):
            lst_table, n_cols, _ = extract_data_pdf_pl(
                pdf,
                lst_table=[],
                page_id=page_id,
                type_data="find_keyword",
                lst_str=key,
            )
            if _ == True:
                lst_col = find_header(pdf, page_id=page_id, n_cols=n_cols)
                break

        while True:
            # print(page_id)
            lst_table, n_cols, _ = extract_data_pdf_pl(
                pdf,
                lst_table=lst_table,
                page_id=page_id + 1,
                type_data="avoid_keyword",
                lst_str=[],
            )
            if _ == True:
                page_id += 1
            else:
                break
        # print(lst_table)
        # print(lst_col)
        df = pd.DataFrame(lst_table, columns=lst_col)
        # df[df[df.columns[0]] != '―']
        return df.replace("", None)

def get_table_from_pdf(id_company, path_save, file, type_ = 'bs'):
    path_file = path_save + f'Data/{id_company}/PDF/{file}'
    df_table = extract_pdf(path_file, type_)
    return df_table 

def get_table(id_company, path_save, save_file = False, return_check = True):
    df_time = pd.read_csv(path_save + f'Data/{id_company}/docs/link.csv')
    checklist = []
    print(f'Get table of {id_company}')
    for quy in ['Q1', 'Q2', 'Q3', 'Q4']:
        for id in df_time.index:
            year = df_time[f'Year'][id]
            check_file = False

            for file in os.listdir(path_save + f'Data/{id_company}/PDF'):
                if file.startswith(f'{year}_{quy}') and '(訂正)' not in file and 'ocr' not in file:
                    check_file = True
                    check_bs = 'Done'
                    try:
                        df_bs = get_table_from_pdf(id_company, path_save, file, type_= 'bs')
                        if save_file:
                            path = path_save + f'Data/{id_company}/table_bs'
                            # Kiểm tra nếu thư mục chưa tồn tại
                            if not os.path.exists(path):
                                # Tạo thư mục
                                os.makedirs(path)
                            df_bs.to_csv(path_save + f'Data/{id_company}/table_bs/{year}_{quy}.csv', index=False)
                    except:
                        check_bs = 'B'

                    check_pl = 'Done'
                    try:
                        df_pl = get_table_from_pdf(id_company, path_save, file, type_= 'pl')
                        if save_file:
                            path = path_save + f'Data/{id_company}/table_pl'
                            # Kiểm tra nếu thư mục chưa tồn tại
                            if not os.path.exists(path):
                                # Tạo thư mục
                                os.makedirs(path)
                            df_pl.to_csv(path_save + f'Data/{id_company}/table_pl/{year}_{quy}.csv', index=False)
                    except:
                        check_pl = 'B'
                    checklist += [[f'{year}_{quy}', check_bs, check_pl]]

            if check_file == False:
                checklist += [[f'{year}_{quy}', 'N/A', 'N/A']]

    df_checklist = pd.DataFrame(checklist, columns=['Time', 'get_bs', 'get_pl'])
    df_checklist.to_csv(path_save + f'Data/{id_company}/docs/checklist_get_table.csv', index = False)
    if return_check:
        return df_checklist



# 9997 Do dịch lỗi: (cid:17082)(cid:17044)(cid:17062)(cid:17079)(cid:17029)(cid:17128)...
# 9995 Văn bản lỗi, các chữ thưa nhau, sai số cột
#      Đã fix lỗi không tìm điểm dừng khi lấy bảng pl--  ok
#      Bảng quá ngắn chứng tỏ sai (lỗi do tìm thấy từ khóa ở trang k phải trang cần tìm)
# 9994: 2008 Q1 Dạng bảng khác, 
#       2016 Q4: dịch lỗi: không ra data bảng

#9990: 2013 Q1: Lỗi bảng ngắn -> tính luôn phần số trang - 7 - -> số cột = 3 sai: 
#       2011 Q4 Thieu keyword

# 9997 Do dịch lỗi: (cid:17082)(cid:17044)(cid:17062)(cid:17079)(cid:17029)(cid:17128)...
# 9995 Văn bản lỗi, các chữ thưa nhau, sai số cột
#      Đã fix lỗi không tìm điểm dừng khi lấy bảng pl--  ok
#      Bảng quá ngắn chứng tỏ sai (lỗi do tìm thấy từ khóa ở trang k phải trang cần tìm)
# 9994: 2008 Q1 Dạng bảng khác, 
#       2016 Q4: dịch lỗi: không ra data bảng

#9990: 2013 Q1: Lỗi bảng ngắn -> tính luôn phần số trang - 7 - -> số cột = 3 sai: 
#       2011 Q4 Thieu keyword

# %%
id_company =  2735
year = 2007
quy = 'Q4'
path_save = ""
for file in os.listdir(path_save + f'Data/{id_company}/PDF'):
    if file.startswith(f'{year}_{quy}') and '(訂正)' not in file and 'ocr' not in file:
        print(file)
        pdf = pdfplumber.open(f'Data/{id_company}/PDF/{file}')
        # print(get_table_from_pdf(id_company, path_save, file, type_= 'pl'))
        # key = pl_text
        # lst_table, n_cols, _ = extract_data_pdf_pl(
        #         pdf,
        #         lst_table=[],
        #         page_id=15,
        #         type_data="avoid_keyword",
        #         lst_str=key,
        #     )
        # print(lst_table, n_cols, _)
        pdf = pdfplumber.open(f'Data/{id_company}/PDF/{file}')
        page = pdf.pages[7]
        text = page.extract_text()

print(text)
# Out:
# 2007_Q4_決算短信(2008_10_20).pdf
# ㈱ワッツ（2735）平成20年8月期決算短信
# ４．連結財務諸表
# (1）連結貸借対照表
# 前連結会計年度 当連結会計年度
# （平成19年８月31日） （平成20年８月31日）
# 注記 構成比 構成比
# 区分 金額（千円） 金額（千円）
# 番号 （％） （％）
# （資産の部）
# Ⅰ 流動資産
# １ 現金及び預金 1,719,912 1,521,426
# ２ 売掛金 1,276,056 1,225,701
# ３ 売上預け金 617,186 839,028
# ４ たな卸資産 2,888,097 3,181,336
# ５ 繰延税金資産 171,834 174,434
# ６ その他 327,367 522,295
# 貸倒引当金 △29,576 △61,494
# 流動資産合計 6,970,878 62.2 7,402,728 65.8
# Ⅱ 固定資産
# １ 有形固定資産
# (1）建物及び構築物 ※２ 678,216 720,165
# 減価償却累計額 ※３ △328,659 349,557 △402,765 317,400
# (2）車両運搬具 8,129 7,079
# 減価償却累計額 △4,705 3,423 △4,783 2,295
# (3）器具備品 1,480,222 1,573,662
# 減価償却累計額 ※２ △958,620 521,602 △1,116,873 456,788
# (4）土地 ※３ 136,845 136,845
# 有形固定資産合計 1,011,429 9.0 913,330 8.1
# ２ 無形固定資産
# (1）のれん 702,472 546,367
# (2）その他 54,065 31,517
# 無形固定資産合計 756,538 6.8 577,885 5.2
# － 8 －

# %%
id_company =  9989
year = 2008
quy = 'Q3'
path_save = ""
pd.read_csv(f'Data/{id_company}/table_pl/{year}_{quy}.csv')
# Out:
#              百万円 当第３四半期連結累計期間
# 0            売上高      176,422
# 1           売上原価      135,479
# 2          売上総利益       40,942
# 3     販売費及び一般管理費       30,028
# 4           営業利益       10,914
# 5          営業外収益          NaN
# 6           受取利息           78
# 7          受取配当金            3
# 8        固定資産受贈益          109
# 9            その他           85
# 10       営業外収益合計          277
# 11         営業外費用          NaN
# 12          支払利息            0
# 13         商品廃棄損           65
# 14           その他            3
# 15       営業外費用合計           69
# 16          経常利益       11,122
# 17          特別利益          NaN
# 18         受取補償金           10
# 19        特別利益合計           10
# 20          特別損失          NaN
# 21       固定資産除却損          111
# 22      賃貸借契約解約損           35
# 23       固定資産売却損            0
# 24          減損損失           90
# 25        特別損失合計          237
# 26  税金等調整前四半期純利益       10,895
# 27          法人税等        4,497
# 28        四半期純利益        6,398

# %%
df = pd.read_csv("docs/List_company_23052023 - Listing.csv")
(df['table']== "Done").sum()
# Out:
# 736

# %%
df
# Out:
#       Symbol  check volume dividend table
# 0       1301   Done   Done     Done  Done
# 1       1332   Done   Done     Done  Done
# 2       1333   Done   Done     Done  Done
# 3       1375   Done   Done     Done  Done
# 4       1376   Done   Done     Done  Done
# 5       1377   Done   Done     Done  Done
# 6       1379   Done   Done     Done  Done
# 7       1380   Done   Done     Done  Done
# 8       1381   Done   Done     Done  Done
# 9       1382   Done  False     Done  Done
# 10      1383   Done   Done     Done  Done
# 11      1384   Done   Done     Done  Done
# 12      1400   Done   Done     Done  Done
# 13      1401   Done  False     Done  Done
# 14      1407   Done   Done     Done  Done
# 15      1414   Done  False     Done  Done
# 16      1417   Done   Done     Done  Done
# 17      1418   Done  False     Done  Done
# 18      1419   Done   Done     Done  Done
# 19      1420   Done   Done     Done  Done
# 20      1429   Done   Done     Done  Done
# 21      1430   Done  False     Done  Done
# 22      1431   Done   Done     Done  Done
# 23      1433   Done   Done     Done  Done
# 24      1434   Done   Done     Done  Done
# 25      1435   Done   Done     Done  Done
# 26      1436   Done   Done     Done  Done
# 27      1438   Done   Done     Done  Done
# 28      1439   Done   Done     Done  Done
# 29      1443   Done   Done     Done  Done
# 30      1444   Done   Done     Done  Done
# 31      1446   Done   Done     Done  Done
# 32      1447   Done   Done     Done  Done
# 33      1450   Done   Done     Done  Done
# 34      1451   Done   Done     Done  Done
# 35      1491   Done  False     Done  Done
# 36      1514   Done   Done     Done  Done
# 37      1515   Done   Done     Done  Done
# 38      1518   Done   Done     Done  Done
# 39      1605   Done   Done     Done  Done
# 40      1662   Done   Done     Done  Done
# 41      1663   Done   Done     Done  Done
# 42      1711   Done  False     Done  Done
# 43      1712   Done  False     Done  Done
# 44      1716   Done   Done     Done  Done
# 45      1717   Done   Done     Done  Done
# 46      1718   Done  False     Done  Done
# 47      1719   Done   Done     Done  Done
# 48      1720   Done   Done     Done  Done
# 49      1721   Done  False     Done  Done
# 50      1723   Done  False     Done  Done
# 51      1724   Done   Done     Done  Done
# 52      1726   Done   Done     Done  Done
# 53      1730   Done  False     Done  Done
# 54      1736   Done   Done     Done  Done
# 55      1739   Done  False     Done  Done
# 56      1743   Done  False     Done  Done
# 57      1757   Done   Done     Done  Done
# 58      1758   Done  False     Done  Done
# 59      1762   Done   Done     Done  Done
# 60      1764   Done   Done     Done  Done
# 61      1766   Done   Done     Done  Done
# 62      1768   Done   Done     Done  Done
# 63      1770   Done   Done     Done  Done
# 64      1773  False    NaN      NaN   NaN
# 65      1775   Done   Done     Done  Done
# 395     2687   Done   Done     Done  Done
# 396     2689   Done   Done     Done  Done
# 397     2692   Done   Done     Done  Done
# 398     2693   Done   Done     Done  Done
# 399     2694   Done   Done     Done  Done
# 400     2695   Done  False     Done  Done
# 401     2698   Done   Done     Done  Done
# 402     2700   Done   Done     Done  Done
# 403     2702   Done   Done     Done  Done
# 404     2705   Done   Done     Done  Done
# 405     2706   Done  False     Done  Done
# 406     2708   Done   Done     Done  Done
# 407     2715   Done   Done     Done  Done
# 408     2721   Done  False     Done  Done
# 409     2722   Done  False     Done  Done
# 410     2726   Done   Done     Done  Done
# 411     2730   Done   Done     Done  Done
# 412     2733   Done   Done     Done  Done
# 413     2734   Done   Done     Done  Done
# 414     2735   Done   Done     Done  Done
# 415     2736   Done   Done     Done  Done
# 416     2737   Done   Done     Done  Done
# 417     2742   Done  False     Done  Done
# 418     2743   Done   Done     Done  Done
# 419     2747   Done   Done     Done  Done
# 420     2749   Done   Done     Done  Done
# 421     2750   Done   Done     Done  Done
# 422     2751   Done   Done     Done  Done
# 423     2752   Done   Done     Done  Done
# 424     2753   Done  False     Done  Done
# 425     2754   Done  False     Done  Done
# 426     2760   Done   Done     Done  Done
# 427     2762   Done  False     Done  Done
# 428     2763  False    NaN      NaN   NaN
# 429     2764  False    NaN      NaN   NaN
# 430     2767  False    NaN      NaN   NaN
# 431     2768  False    NaN      NaN   NaN
# 432     2769  False    NaN      NaN   NaN
# 433     2776  False    NaN      NaN   NaN
# 434     2778  False    NaN      NaN   NaN
# 435     2780  False    NaN      NaN   NaN
# 436     2782  False    NaN      NaN   NaN
# 437     2784  False    NaN      NaN   NaN
# 438     2788  False    NaN      NaN   NaN
# 439     2789  False    NaN      NaN   NaN
# 440     2790  False    NaN      NaN   NaN
# 441     2791  False    NaN      NaN   NaN
# 442     2792  False    NaN      NaN   NaN
# 443     2795  False    NaN      NaN   NaN
# 444     2796  False    NaN      NaN   NaN
# 445     2798  False    NaN      NaN   NaN
# 446     2801  False    NaN      NaN   NaN
# 447     2802  False    NaN      NaN   NaN
# 448     2804  False    NaN      NaN   NaN
# 449     2805  False    NaN      NaN   NaN
# 450     2806  False    NaN      NaN   NaN
# 451     2809  False    NaN      NaN   NaN
# 452     2810  False    NaN      NaN   NaN
# 453     2811  False    NaN      NaN   NaN
# 454     2812  False    NaN      NaN   NaN
# 455     2813  False    NaN      NaN   NaN
# 456     2814  False    NaN      NaN   NaN
# 457     2815  False    NaN      NaN   NaN
# 458     2816  False    NaN      NaN   NaN
# 459     2818  False    NaN      NaN   NaN
# 460     2819  False    NaN      NaN   NaN
# 461     2820  False    NaN      NaN   NaN
# 462     2830  False    NaN      NaN   NaN
# 463     2831  False    NaN      NaN   NaN
# 464     2871  False    NaN      NaN   NaN
# 465     2872  False    NaN      NaN   NaN
# 466     2874  False    NaN      NaN   NaN
# 467     2875  False    NaN      NaN   NaN
# 468     2876  False    NaN      NaN   NaN
# 469     2877  False    NaN      NaN   NaN
# 470     2882  False    NaN      NaN   NaN
# 471     2883  False    NaN      NaN   NaN
# 472     2884  False    NaN      NaN   NaN
# 473     2892  False    NaN      NaN   NaN
# 474     2894  False    NaN      NaN   NaN
# 475     2897  False    NaN      NaN   NaN
# 476     2899  False    NaN      NaN   NaN
# 477     2901  False    NaN      NaN   NaN
# 478     2903  False    NaN      NaN   NaN
# 479     2904  False    NaN      NaN   NaN
# 480     2907  False    NaN      NaN   NaN
# 481     2908  False    NaN      NaN   NaN
# 482     2910  False    NaN      NaN   NaN
# 483     2911  False    NaN      NaN   NaN
# 484     2914  False    NaN      NaN   NaN
# 485     2915  False    NaN      NaN   NaN
# 486     2916  False    NaN      NaN   NaN
# 487     2917  False    NaN      NaN   NaN
# 488     2918  False    NaN      NaN   NaN
# 489     2922  False    NaN      NaN   NaN
# 490     2923  False    NaN      NaN   NaN
# 491     2924  False    NaN      NaN   NaN
# 492     2926  False    NaN      NaN   NaN
# 493     2927  False    NaN      NaN   NaN
# 494     2929  False    NaN      NaN   NaN
# 495     2930  False    NaN      NaN   NaN
# 496     2931  False    NaN      NaN   NaN
# 497     2932  False    NaN      NaN   NaN
# 498     2933  False    NaN      NaN   NaN
# 499     2934  False    NaN      NaN   NaN
# 500     2935  False    NaN      NaN   NaN
# 501     2936  False    NaN      NaN   NaN
# 502     2937  False    NaN      NaN   NaN
# 503     2961  False    NaN      NaN   NaN
# 504     2970  False    NaN      NaN   NaN
# 505     2975  False    NaN      NaN   NaN
# 506     2978  False    NaN      NaN   NaN
# 507     2980  False    NaN      NaN   NaN
# 508     2981  False    NaN      NaN   NaN
# 509     2982  False    NaN      NaN   NaN
# 510     2983  False    NaN      NaN   NaN
# 511     2984  False    NaN      NaN   NaN
# 512     2986  False    NaN      NaN   NaN
# 513     2987  False    NaN      NaN   NaN
# 514     2991  False    NaN      NaN   NaN
# 515     2993  False    NaN      NaN   NaN
# 516     2997  False    NaN      NaN   NaN
# 517     2998  False    NaN      NaN   NaN
# 518     2999  False    NaN      NaN   NaN
# 519     3001  False    NaN      NaN   NaN
# 520     3002  False    NaN      NaN   NaN
# 521     3003  False    NaN      NaN   NaN
# 522     3004  False    NaN      NaN   NaN
# 523     3010  False    NaN      NaN   NaN
# 524     3011  False    NaN      NaN   NaN
# 525     3020  False    NaN      NaN   NaN
# 526     3021  False    NaN      NaN   NaN
# 527     3023  False    NaN      NaN   NaN
# 528     3024  False    NaN      NaN   NaN
# 529     3028  False    NaN      NaN   NaN
# 530     3030  False    NaN      NaN   NaN
# 531     3031  False    NaN      NaN   NaN
# 532     3034  False    NaN      NaN   NaN
# 533     3035  False    NaN      NaN   NaN
# 534     3036  False    NaN      NaN   NaN
# 535     3038  False    NaN      NaN   NaN
# 536     3040  False    NaN      NaN   NaN
# 537     3041  False    NaN      NaN   NaN
# 538     3042  False    NaN      NaN   NaN
# 539     3045  False    NaN      NaN   NaN
# 540     3046  False    NaN      NaN   NaN
# 541     3048  False    NaN      NaN   NaN
# 542     3050  False    NaN      NaN   NaN
# 543     3053  False    NaN      NaN   NaN
# 544     3054  False    NaN      NaN   NaN
# 545     3058  False    NaN      NaN   NaN
# 546     3059  False    NaN      NaN   NaN
# 547     3063  False    NaN      NaN   NaN
# 548     3064  False    NaN      NaN   NaN
# 549     3065  False    NaN      NaN   NaN
# 550     3067  False    NaN      NaN   NaN
# 551     3068  False    NaN      NaN   NaN
# 552     3069  False    NaN      NaN   NaN
# 553     3070  False    NaN      NaN   NaN
# 554     3071  False    NaN      NaN   NaN
# 555     3073  False    NaN      NaN   NaN
# 556     3075  False    NaN      NaN   NaN
# 557     3076  False    NaN      NaN   NaN
# 558     3077  False    NaN      NaN   NaN
# 559     3079  False    NaN      NaN   NaN
# 560     3080  False    NaN      NaN   NaN
# 561     3082  False    NaN      NaN   NaN
# 562     3083  False    NaN      NaN   NaN
# 563     3085  False    NaN      NaN   NaN
# 564     3086  False    NaN      NaN   NaN
# 565     3087  False    NaN      NaN   NaN
# 566     3088  False    NaN      NaN   NaN
# 567     3089  False    NaN      NaN   NaN
# 568     3091  False    NaN      NaN   NaN
# 569     3092  False    NaN      NaN   NaN
# 570     3093  False    NaN      NaN   NaN
# 571     3094  False    NaN      NaN   NaN
# 572     3096  False    NaN      NaN   NaN
# 573     3097  False    NaN      NaN   NaN
# 574     3099  False    NaN      NaN   NaN
# 575     3101  False    NaN      NaN   NaN
# 576     3103  False    NaN      NaN   NaN
# 577     3104  False    NaN      NaN   NaN
# 578     3105  False    NaN      NaN   NaN
# 579     3106  False    NaN      NaN   NaN
# 580     3107  False    NaN      NaN   NaN
# 581     3109  False    NaN      NaN   NaN
# 582     3110  False    NaN      NaN   NaN
# 583     3111  False    NaN      NaN   NaN
# 584     3113  False    NaN      NaN   NaN
# 585     3116  False    NaN      NaN   NaN
# 586     3121  False    NaN      NaN   NaN
# 587     3123  False    NaN      NaN   NaN
# 588     3131  False    NaN      NaN   NaN
# 589     3132  False    NaN      NaN   NaN
# 590     3133  False    NaN      NaN   NaN
# 591     3134  False    NaN      NaN   NaN
# 592     3135  False    NaN      NaN   NaN
# 593     3137  False    NaN      NaN   NaN
# 594     3138  False    NaN      NaN   NaN
# 595     3139  False    NaN      NaN   NaN
# 596     3140  False    NaN      NaN   NaN
# 597     3141  False    NaN      NaN   NaN
# 598     3143  False    NaN      NaN   NaN
# 599     3148  False    NaN      NaN   NaN
# 600     3150  False    NaN      NaN   NaN
# 601     3151  False    NaN      NaN   NaN
# 602     3153  False    NaN      NaN   NaN
# 603     3154  False    NaN      NaN   NaN
# 604     3156  False    NaN      NaN   NaN
# 605     3157  False    NaN      NaN   NaN
# 606     3159  False    NaN      NaN   NaN
# 607     3160  False    NaN      NaN   NaN
# 608     3161  False    NaN      NaN   NaN
# 609     3166  False    NaN      NaN   NaN
# 610     3167  False    NaN      NaN   NaN
# 611     3168  False    NaN      NaN   NaN
# 612     3169  False    NaN      NaN   NaN
# 613     3172  False    NaN      NaN   NaN
# 614     3173  False    NaN      NaN   NaN
# 615     3174  False    NaN      NaN   NaN
# 616     3175  False    NaN      NaN   NaN
# 617     3176  False    NaN      NaN   NaN
# 618     3177  False    NaN      NaN   NaN
# 619     3178  False    NaN      NaN   NaN
# 620     3179  False    NaN      NaN   NaN
# 621     3180  False    NaN      NaN   NaN
# 622     3181  False    NaN      NaN   NaN
# 623     3182  False    NaN      NaN   NaN
# 624     3183  False    NaN      NaN   NaN
# 625     3184  False    NaN      NaN   NaN
# 626     3185  False    NaN      NaN   NaN
# 627     3186  False    NaN      NaN   NaN
# 628     3187  False    NaN      NaN   NaN
# 629     3189  False    NaN      NaN   NaN
# 630     3190  False    NaN      NaN   NaN
# 631     3191  False    NaN      NaN   NaN
# 632     3192  False    NaN      NaN   NaN
# 633     3193  False    NaN      NaN   NaN
# 634     3195  False    NaN      NaN   NaN
# 635     3196  False    NaN      NaN   NaN
# 636     3197  False    NaN      NaN   NaN
# 637     3198  False    NaN      NaN   NaN
# 638     3199  False    NaN      NaN   NaN
# 639     3201  False    NaN      NaN   NaN
# 640     3202  False    NaN      NaN   NaN
# 641     3204  False    NaN      NaN   NaN
# 642     3205  False    NaN      NaN   NaN
# 643     3221  False    NaN      NaN   NaN
# 644     3222  False    NaN      NaN   NaN
# 645     3223  False    NaN      NaN   NaN
# 646     3224  False    NaN      NaN   NaN
# 647     3228  False    NaN      NaN   NaN
# 648     3231  False    NaN      NaN   NaN
# 649     3232  False    NaN      NaN   NaN
# 650     3236  False    NaN      NaN   NaN
# 651     3237  False    NaN      NaN   NaN
# 652     3238  False    NaN      NaN   NaN
# 653     3241  False    NaN      NaN   NaN
# 654     3242  False    NaN      NaN   NaN
# 655     3244  False    NaN      NaN   NaN
# 656     3245  False    NaN      NaN   NaN
# 657     3246  False    NaN      NaN   NaN
# 658     3248  False    NaN      NaN   NaN
# 659     3252  False    NaN      NaN   NaN
# 660     3254  False    NaN      NaN   NaN
# 661     3261  False    NaN      NaN   NaN
# 662     3264  False    NaN      NaN   NaN
# 663     3266  False    NaN      NaN   NaN
# 664     3267  False    NaN      NaN   NaN
# 665     3271  False    NaN      NaN   NaN
# 666     3275  False    NaN      NaN   NaN
# 667     3276  False    NaN      NaN   NaN
# 668     3277  False    NaN      NaN   NaN
# 669     3280  False    NaN      NaN   NaN
# 670     3284  False    NaN      NaN   NaN
# 671     3286  False    NaN      NaN   NaN
# 672     3288  False    NaN      NaN   NaN
# 673     3289  False    NaN      NaN   NaN
# 674     3291  False    NaN      NaN   NaN
# 675     3293  False    NaN      NaN   NaN
# 676     3294  False    NaN      NaN   NaN
# 677     3297  False    NaN      NaN   NaN
# 678     3299  False    NaN      NaN   NaN
# 679     3300  False    NaN      NaN   NaN
# 680     3302  False    NaN      NaN   NaN
# 681     3306  False    NaN      NaN   NaN
# 682     3315  False    NaN      NaN   NaN
# 683     3316  False    NaN      NaN   NaN
# 684     3317  False    NaN      NaN   NaN
# 685     3319  False    NaN      NaN   NaN
# 686     3320  False    NaN      NaN   NaN
# 687     3321  False    NaN      NaN   NaN
# 688     3322  False    NaN      NaN   NaN
# 689     3323  False    NaN      NaN   NaN
# 690     3326  False    NaN      NaN   NaN
# 691     3328  False    NaN      NaN   NaN
# 692     3329  False    NaN      NaN   NaN
# 693     3333  False    NaN      NaN   NaN
# 694     3341  False    NaN      NaN   NaN
# 695     3347  False    NaN      NaN   NaN
# 696     3349  False    NaN      NaN   NaN
# 697     3350  False    NaN      NaN   NaN
# 698     3352  False    NaN      NaN   NaN
# 699     3353  False    NaN      NaN   NaN
# 700     3355  False    NaN      NaN   NaN
# 701     3358  False    NaN      NaN   NaN
# 702     3359  False    NaN      NaN   NaN
# 703     3360  False    NaN      NaN   NaN
# 704     3361  False    NaN      NaN   NaN
# 705     3370  False    NaN      NaN   NaN
# 706     3371  False    NaN      NaN   NaN
# 707     3372  False    NaN      NaN   NaN
# 708     3374  False    NaN      NaN   NaN
# 709     3375  False    NaN      NaN   NaN
# 710     3377  False    NaN      NaN   NaN
# 711     3382  False    NaN      NaN   NaN
# 712     3386  False    NaN      NaN   NaN
# 713     3387  False    NaN      NaN   NaN
# 714     3388  False    NaN      NaN   NaN
# 715     3391  False    NaN      NaN   NaN
# 716     3392  False    NaN      NaN   NaN
# 717     3393  False    NaN      NaN   NaN
# 718     3395  False    NaN      NaN   NaN
# 719     3396  False    NaN      NaN   NaN
# 720     3397  False    NaN      NaN   NaN
# 721     3399  False    NaN      NaN   NaN
# 722     3401  False    NaN      NaN   NaN
# 723     3402  False    NaN      NaN   NaN
# 724     3405  False    NaN      NaN   NaN
# 725     3407  False    NaN      NaN   NaN
# 726     3409  False    NaN      NaN   NaN
# 727     3415  False    NaN      NaN   NaN
# 728     3416  False    NaN      NaN   NaN
# 729     3417  False    NaN      NaN   NaN
# 730     3418  False    NaN      NaN   NaN
# 731     3420  False    NaN      NaN   NaN
# 732     3421  False    NaN      NaN   NaN
# 733     3422  False    NaN      NaN   NaN
# 734     3423  False    NaN      NaN   NaN
# 735     3426  False    NaN      NaN   NaN
# 736     3431  False    NaN      NaN   NaN
# 737     3433  False    NaN      NaN   NaN
# 738     3434  False    NaN      NaN   NaN
# 739     3435  False    NaN      NaN   NaN
# 740     3436  False    NaN      NaN   NaN
# 741     3437  False    NaN      NaN   NaN
# 742     3439  False    NaN      NaN   NaN
# 743     3440  False    NaN      NaN   NaN
# 744     3441  False    NaN      NaN   NaN
# 745     3443  False    NaN      NaN   NaN
# 746     3444  False    NaN      NaN   NaN
# 747     3445  False    NaN      NaN   NaN
# 748     3446  False    NaN      NaN   NaN
# 749     3447  False    NaN      NaN   NaN
# 750     3449  False    NaN      NaN   NaN
# 751     3452  False    NaN      NaN   NaN
# 752     3454  False    NaN      NaN   NaN
# 753     3457  False    NaN      NaN   NaN
# 754     3458  False    NaN      NaN   NaN
# 755     3461  False    NaN      NaN   NaN
# 756     3464  False    NaN      NaN   NaN
# 757     3465  False    NaN      NaN   NaN
# 758     3467  False    NaN      NaN   NaN
# 759     3469  False    NaN      NaN   NaN
# 760     3474  False    NaN      NaN   NaN
# 761     3475  False    NaN      NaN   NaN
# 762     3477  False    NaN      NaN   NaN
# 763     3479  False    NaN      NaN   NaN
# 764     3480  False    NaN      NaN   NaN
# 765     3482  False    NaN      NaN   NaN
# 766     3484  False    NaN      NaN   NaN
# 767     3486  False    NaN      NaN   NaN
# 768     3489  False    NaN      NaN   NaN
# 769     3490  False    NaN      NaN   NaN
# 770     3491  False    NaN      NaN   NaN
# 771     3494  False    NaN      NaN   NaN
# 772     3495  False    NaN      NaN   NaN
# 773     3496  False    NaN      NaN   NaN
# 774     3497  False    NaN      NaN   NaN
# 775     3498  False    NaN      NaN   NaN
# 776     3501  False    NaN      NaN   NaN
# 777     3512  False    NaN      NaN   NaN
# 778     3513  False    NaN      NaN   NaN
# 779     3521  False    NaN      NaN   NaN
# 780     3524  False    NaN      NaN   NaN
# 781     3526  False    NaN      NaN   NaN
# 782     3529  False    NaN      NaN   NaN
# 783     3536  False    NaN      NaN   NaN
# 784     3537  False    NaN      NaN   NaN
# 785     3538  False    NaN      NaN   NaN
# 786     3539  False    NaN      NaN   NaN
# 787     3540  False    NaN      NaN   NaN
# 788     3541  False    NaN      NaN   NaN
# 789     3542  False    NaN      NaN   NaN
# 790     3543  False    NaN      NaN   NaN
# 791     3544  False    NaN      NaN   NaN
# 792     3546  False    NaN      NaN   NaN
# 793     3547  False    NaN      NaN   NaN
# 794     3548  False    NaN      NaN   NaN
# 795     3549  False    NaN      NaN   NaN
# 796     3550  False    NaN      NaN   NaN
# 797     3551  False    NaN      NaN   NaN
# 798     3553  False    NaN      NaN   NaN
# 799     3556  False    NaN      NaN   NaN
# 800     3557  False    NaN      NaN   NaN
# 801     3558  False    NaN      NaN   NaN
# 802     3559  False    NaN      NaN   NaN
# 803     3560  False    NaN      NaN   NaN
# 804     3561  False    NaN      NaN   NaN
# 805     3562  False    NaN      NaN   NaN
# 806     3563  False    NaN      NaN   NaN
# 807     3565  False    NaN      NaN   NaN
# 808     3566  False    NaN      NaN   NaN
# 809     3569  False    NaN      NaN   NaN
# 810     3571  False    NaN      NaN   NaN
# 811     3577  False    NaN      NaN   NaN
# 812     3580  False    NaN      NaN   NaN
# 813     3583  False    NaN      NaN   NaN
# 814     3591  False    NaN      NaN   NaN
# 815     3593  False    NaN      NaN   NaN
# 816     3597  False    NaN      NaN   NaN
# 817     3598  False    NaN      NaN   NaN
# 818     3600  False    NaN      NaN   NaN
# 819     3604  False    NaN      NaN   NaN
# 820     3607  False    NaN      NaN   NaN
# 821     3608  False    NaN      NaN   NaN
# 822     3611  False    NaN      NaN   NaN
# 823     3612  False    NaN      NaN   NaN
# 824     3622  False    NaN      NaN   NaN
# 825     3623  False    NaN      NaN   NaN
# 826     3624  False    NaN      NaN   NaN
# 827     3625  False    NaN      NaN   NaN
# 828     3626  False    NaN      NaN   NaN
# 829     3627  False    NaN      NaN   NaN
# 830     3628  False    NaN      NaN   NaN
# 831     3632  False    NaN      NaN   NaN
# 832     3633  False    NaN      NaN   NaN
# 833     3634  False    NaN      NaN   NaN
# 834     3635  False    NaN      NaN   NaN
# 835     3636  False    NaN      NaN   NaN
# 836     3639  False    NaN      NaN   NaN
# 837     3640  False    NaN      NaN   NaN
# 838     3641  False    NaN      NaN   NaN
# 839     3645  False    NaN      NaN   NaN
# 840     3646  False    NaN      NaN   NaN
# 841     3647  False    NaN      NaN   NaN
# 842     3648  False    NaN      NaN   NaN
# 843     3649  False    NaN      NaN   NaN
# 844     3652  False    NaN      NaN   NaN
# 845     3653  False    NaN      NaN   NaN
# 846     3655  False    NaN      NaN   NaN
# 847     3656  False    NaN      NaN   NaN
# 848     3657  False    NaN      NaN   NaN
# 849     3659  False    NaN      NaN   NaN
# 850     3660  False    NaN      NaN   NaN
# 851     3661  False    NaN      NaN   NaN
# 852     3662  False    NaN      NaN   NaN
# 853     3663  False    NaN      NaN   NaN
# 854     3664  False    NaN      NaN   NaN
# 855     3665  False    NaN      NaN   NaN
# 856     3666  False    NaN      NaN   NaN
# 857     3667  False    NaN      NaN   NaN
# 858     3668  False    NaN      NaN   NaN
# 859     3670  False    NaN      NaN   NaN
# 860     3671  False    NaN      NaN   NaN
# 861     3672  False    NaN      NaN   NaN
# 862     3673  False    NaN      NaN   NaN
# 863     3674  False    NaN      NaN   NaN
# 864     3675  False    NaN      NaN   NaN
# 865     3676  False    NaN      NaN   NaN
# 866     3677  False    NaN      NaN   NaN
# 867     3678  False    NaN      NaN   NaN
# 868     3679  False    NaN      NaN   NaN
# 869     3680  False    NaN      NaN   NaN
# 870     3681  False    NaN      NaN   NaN
# 871     3682  False    NaN      NaN   NaN
# 872     3683  False    NaN      NaN   NaN
# 873     3686  False    NaN      NaN   NaN
# 874     3687  False    NaN      NaN   NaN
# 875     3688  False    NaN      NaN   NaN
# 876     3690  False    NaN      NaN   NaN
# 877     3691  False    NaN      NaN   NaN
# 878     3692  False    NaN      NaN   NaN
# 879     3694  False    NaN      NaN   NaN
# 880     3695  False    NaN      NaN   NaN
# 881     3696  False    NaN      NaN   NaN
# 882     3697  False    NaN      NaN   NaN
# 883     3698  False    NaN      NaN   NaN
# 884     3708  False    NaN      NaN   NaN
# 885     3710  False    NaN      NaN   NaN
# 886     3712  False    NaN      NaN   NaN
# 887     3719  False    NaN      NaN   NaN
# 888     3723  False    NaN      NaN   NaN
# 889     3726  False    NaN      NaN   NaN
# 890     3727  False    NaN      NaN   NaN
# 891     3733  False    NaN      NaN   NaN
# 892     3738  False    NaN      NaN   NaN
# 893     3741  False    NaN      NaN   NaN
# 894     3744  False    NaN      NaN   NaN
# 895     3747  False    NaN      NaN   NaN
# 896     3750  False    NaN      NaN   NaN
# 897     3753  False    NaN      NaN   NaN
# 898     3758  False    NaN      NaN   NaN
# 899     3760  False    NaN      NaN   NaN
# 900     3762  False    NaN      NaN   NaN
# 901     3763  False    NaN      NaN   NaN
# 902     3765  False    NaN      NaN   NaN
# 903     3766  False    NaN      NaN   NaN
# 904     3768  False    NaN      NaN   NaN
# 905     3769  False    NaN      NaN   NaN
# 906     3770  False    NaN      NaN   NaN
# 907     3771  False    NaN      NaN   NaN
# 908     3772  False    NaN      NaN   NaN
# 909     3773  False    NaN      NaN   NaN
# 910     3774  False    NaN      NaN   NaN
# 911     3776  False    NaN      NaN   NaN
# 912     3777  False    NaN      NaN   NaN
# 913     3778  False    NaN      NaN   NaN
# 914     3779  False    NaN      NaN   NaN
# 915     3782  False    NaN      NaN   NaN
# 916     3784  False    NaN      NaN   NaN
# 917     3787  False    NaN      NaN   NaN
# 918     3788  False    NaN      NaN   NaN
# 919     3791  False    NaN      NaN   NaN
# 920     3793  False    NaN      NaN   NaN
# 921     3796  False    NaN      NaN   NaN
# 922     3798  False    NaN      NaN   NaN
# 923     3799  False    NaN      NaN   NaN
# 924     3800  False    NaN      NaN   NaN
# 925     3802  False    NaN      NaN   NaN
# 926     3803  False    NaN      NaN   NaN
# 927     3804  False    NaN      NaN   NaN
# 928     3807  False    NaN      NaN   NaN
# 929     3810  False    NaN      NaN   NaN
# 930     3814  False    NaN      NaN   NaN
# 931     3815  False    NaN      NaN   NaN
# 932     3816  False    NaN      NaN   NaN
# 933     3817  False    NaN      NaN   NaN
# 934     3823  False    NaN      NaN   NaN
# 935     3825  False    NaN      NaN   NaN
# 936     3826  False    NaN      NaN   NaN
# 937     3834  False    NaN      NaN   NaN
# 938     3835  False    NaN      NaN   NaN
# 939     3836  False    NaN      NaN   NaN
# 940     3837  False    NaN      NaN   NaN
# 941     3839  False    NaN      NaN   NaN
# 942     3840  False    NaN      NaN   NaN
# 943     3841  False    NaN      NaN   NaN
# 944     3842  False    NaN      NaN   NaN
# 945     3843  False    NaN      NaN   NaN
# 946     3844  False    NaN      NaN   NaN
# 947     3845  False    NaN      NaN   NaN
# 948     3847  False    NaN      NaN   NaN
# 949     3848  False    NaN      NaN   NaN
# 950     3850  False    NaN      NaN   NaN
# 951     3851  False    NaN      NaN   NaN
# 952     3852  False    NaN      NaN   NaN
# 953     3853  False    NaN      NaN   NaN
# 954     3854  False    NaN      NaN   NaN
# 955     3856  False    NaN      NaN   NaN
# 956     3857  False    NaN      NaN   NaN
# 957     3858  False    NaN      NaN   NaN
# 958     3861  False    NaN      NaN   NaN
# 959     3863  False    NaN      NaN   NaN
# 960     3864  False    NaN      NaN   NaN
# 961     3865  False    NaN      NaN   NaN
# 962     3877  False    NaN      NaN   NaN
# 963     3878  False    NaN      NaN   NaN
# 964     3880  False    NaN      NaN   NaN
# 965     3891  False    NaN      NaN   NaN
# 966     3892  False    NaN      NaN   NaN
# 967     3895  False    NaN      NaN   NaN
# 968     3896  False    NaN      NaN   NaN
# 969     3900  False    NaN      NaN   NaN
# 970     3901  False    NaN      NaN   NaN
# 971     3902  False    NaN      NaN   NaN
# 972     3903  False    NaN      NaN   NaN
# 973     3904  False    NaN      NaN   NaN
# 974     3905  False    NaN      NaN   NaN
# 975     3907  False    NaN      NaN   NaN
# 976     3908  False    NaN      NaN   NaN
# 977     3909  False    NaN      NaN   NaN
# 978     3910  False    NaN      NaN   NaN
# 979     3911  False    NaN      NaN   NaN
# 980     3912  False    NaN      NaN   NaN
# 981     3913  False    NaN      NaN   NaN
# 982     3914  False    NaN      NaN   NaN
# 983     3915  False    NaN      NaN   NaN
# 984     3916  False    NaN      NaN   NaN
# 985     3917  False    NaN      NaN   NaN
# 986     3918  False    NaN      NaN   NaN
# 987     3920  False    NaN      NaN   NaN
# 988     3921  False    NaN      NaN   NaN
# 989     3922  False    NaN      NaN   NaN
# 990     3923  False    NaN      NaN   NaN
# 991     3924  False    NaN      NaN   NaN
# 992     3925  False    NaN      NaN   NaN
# 993     3926  False    NaN      NaN   NaN
# 994     3927  False    NaN      NaN   NaN
# 995     3928  False    NaN      NaN   NaN
# 996     3929  False    NaN      NaN   NaN
# 997     3930  False    NaN      NaN   NaN
# 998     3931  False    NaN      NaN   NaN
# 999     3932  False    NaN      NaN   NaN
# 1000    3933  False    NaN      NaN   NaN
# 1001    3934  False    NaN      NaN   NaN
# 1002    3935  False    NaN      NaN   NaN
# 1003    3936  False    NaN      NaN   NaN
# 1004    3937  False    NaN      NaN   NaN
# 1005    3939  False    NaN      NaN   NaN
# 1006    3940  False    NaN      NaN   NaN
# 1007    3941  False    NaN      NaN   NaN
# 1008    3943  False    NaN      NaN   NaN
# 1009    3944  False    NaN      NaN   NaN
# 1010    3945  False    NaN      NaN   NaN
# 1011    3946  False    NaN      NaN   NaN
# 1012    3947  False    NaN      NaN   NaN
# 1013    3948  False    NaN      NaN   NaN
# 1014    3950  False    NaN      NaN   NaN
# 1015    3951  False    NaN      NaN   NaN
# 1016    3953  False    NaN      NaN   NaN
# 1017    3954  False    NaN      NaN   NaN
# 1018    3955  False    NaN      NaN   NaN
# 1019    3961  False    NaN      NaN   NaN
# 1020    3962  False    NaN      NaN   NaN
# 1021    3963  False    NaN      NaN   NaN
# 1022    3964  False    NaN      NaN   NaN
# 1023    3965  False    NaN      NaN   NaN
# 1024    3967  False    NaN      NaN   NaN
# 1025    3968  False    NaN      NaN   NaN
# 1026    3969  False    NaN      NaN   NaN
# 1027    3970  False    NaN      NaN   NaN
# 1028    3974  False    NaN      NaN   NaN
# 1029    3976  False    NaN      NaN   NaN
# 1030    3978  False    NaN      NaN   NaN
# 1031    3979  False    NaN      NaN   NaN
# 1032    3981  False    NaN      NaN   NaN
# 1033    3983  False    NaN      NaN   NaN
# 1034    3984  False    NaN      NaN   NaN
# 1035    3985  False    NaN      NaN   NaN
# 1036    3986  False    NaN      NaN   NaN
# 1037    3987  False    NaN      NaN   NaN
# 1038    3988  False    NaN      NaN   NaN
# 1039    3989  False    NaN      NaN   NaN
# 1040    3990  False    NaN      NaN   NaN
# 1041    3991  False    NaN      NaN   NaN
# 1042    3992  False    NaN      NaN   NaN
# 1043    3993  False    NaN      NaN   NaN
# 1044    3994  False    NaN      NaN   NaN
# 1045    3995  False    NaN      NaN   NaN
# 1046    3996  False    NaN      NaN   NaN
# 1047    3997  False    NaN      NaN   NaN
# 1048    3998  False    NaN      NaN   NaN
# 1049    4004  False    NaN      NaN   NaN
# 1050    4005  False    NaN      NaN   NaN
# 1051    4008  False    NaN      NaN   NaN
# 1052    4011  False    NaN      NaN   NaN
# 1053    4012  False    NaN      NaN   NaN
# 1054    4013  False    NaN      NaN   NaN
# 1055    4014  False    NaN      NaN   NaN
# 1056    4015  False    NaN      NaN   NaN
# 1057    4016  False    NaN      NaN   NaN
# 1058    4017  False    NaN      NaN   NaN
# 1059    4019  False    NaN      NaN   NaN
# 1060    4020  False    NaN      NaN   NaN
# 1061    4021  False    NaN      NaN   NaN
# 1062    4022  False    NaN      NaN   NaN
# 1063    4023  False    NaN      NaN   NaN
# 1064    4025  False    NaN      NaN   NaN
# 1065    4026  False    NaN      NaN   NaN
# 1066    4027  False    NaN      NaN   NaN
# 1067    4028  False    NaN      NaN   NaN
# 1068    4031  False    NaN      NaN   NaN
# 1069    4040  False    NaN      NaN   NaN
# 1070    4041  False    NaN      NaN   NaN
# 1071    4042  False    NaN      NaN   NaN
# 1072    4043  False    NaN      NaN   NaN
# 1073    4044  False    NaN      NaN   NaN
# 1074    4045  False    NaN      NaN   NaN
# 1075    4046  False    NaN      NaN   NaN
# 1076    4047  False    NaN      NaN   NaN
# 1077    4051  False    NaN      NaN   NaN
# 1078    4052  False    NaN      NaN   NaN
# 1079    4053  False    NaN      NaN   NaN
# 1080    4054  False    NaN      NaN   NaN
# 1081    4055  False    NaN      NaN   NaN
# 1082    4056  False    NaN      NaN   NaN
# 1083    4057  False    NaN      NaN   NaN
# 1084    4058  False    NaN      NaN   NaN
# 1085    4059  False    NaN      NaN   NaN
# 1086    4060  False    NaN      NaN   NaN
# 1087    4061  False    NaN      NaN   NaN
# 1088    4062  False    NaN      NaN   NaN
# 1089    4063  False    NaN      NaN   NaN
# 1090    4064  False    NaN      NaN   NaN
# 1091    4068  False    NaN      NaN   NaN
# 1092    4069  False    NaN      NaN   NaN
# 1093    4071  False    NaN      NaN   NaN
# 1094    4072  False    NaN      NaN   NaN
# 1095    4073  False    NaN      NaN   NaN
# 1096    4074  False    NaN      NaN   NaN
# 1097    4075  False    NaN      NaN   NaN
# 1098    4076  False    NaN      NaN   NaN
# 1099    4078  False    NaN      NaN   NaN
# 1100    4080  False    NaN      NaN   NaN
# 1101    4082  False    NaN      NaN   NaN
# 1102    4088  False    NaN      NaN   NaN
# 1103    4091  False    NaN      NaN   NaN
# 1104    4092  False    NaN      NaN   NaN
# 1105    4093  False    NaN      NaN   NaN
# 1106    4094  False    NaN      NaN   NaN
# 1107    4095  False    NaN      NaN   NaN
# 1108    4097  False    NaN      NaN   NaN
# 1109    4098  False    NaN      NaN   NaN
# 1110    4099  False    NaN      NaN   NaN
# 1111    4100  False    NaN      NaN   NaN
# 1112    4102  False    NaN      NaN   NaN
# 1113    4107  False    NaN      NaN   NaN
# 1114    4109  False    NaN      NaN   NaN
# 1115    4112  False    NaN      NaN   NaN
# 1116    4113  False    NaN      NaN   NaN
# 1117    4114  False    NaN      NaN   NaN
# 1118    4116  False    NaN      NaN   NaN
# 1119    4118  False    NaN      NaN   NaN
# 1120    4119  False    NaN      NaN   NaN
# 1121    4120  False    NaN      NaN   NaN
# 1122    4124  False    NaN      NaN   NaN
# 1123    4125  False    NaN      NaN   NaN
# 1124    4151  False    NaN      NaN   NaN
# 1125    4165  False    NaN      NaN   NaN
# 1126    4166  False    NaN      NaN   NaN
# 1127    4167  False    NaN      NaN   NaN
# 1128    4168  False    NaN      NaN   NaN
# 1129    4169  False    NaN      NaN   NaN
# 1130    4170  False    NaN      NaN   NaN
# 1131    4171  False    NaN      NaN   NaN
# 1132    4172  False    NaN      NaN   NaN
# 1133    4173  False    NaN      NaN   NaN
# 1134    4174  False    NaN      NaN   NaN
# 1135    4175  False    NaN      NaN   NaN
# 1136    4176  False    NaN      NaN   NaN
# 1137    4177  False    NaN      NaN   NaN
# 1138    4178  False    NaN      NaN   NaN
# 1139    4179  False    NaN      NaN   NaN
# 1140    4180  False    NaN      NaN   NaN
# ...
# 3430    9099  False    NaN      NaN   NaN
# 3431    9101  False    NaN      NaN   NaN
# 3432    9104  False    NaN      NaN   NaN
# 3433    9107  False    NaN      NaN   NaN
# 3434    9110  False    NaN      NaN   NaN
# 3435    9115  False    NaN      NaN   NaN
# 3436    9119  False    NaN      NaN   NaN
# 3437    9127  False    NaN      NaN   NaN
# 3438    9130  False    NaN      NaN   NaN
# 3439    9142  False    NaN      NaN   NaN
# 3440    9143  False    NaN      NaN   NaN
# 3441    9145  False    NaN      NaN   NaN
# 3442    9147  False    NaN      NaN   NaN
# 3443    9171  False    NaN      NaN   NaN
# 3444    9173  False    NaN      NaN   NaN
# 3445    9193  False    NaN      NaN   NaN
# 3446    9201  False    NaN      NaN   NaN
# 3447    9202  False    NaN      NaN   NaN
# 3448    9204  False    NaN      NaN   NaN
# 3449    9206  False    NaN      NaN   NaN
# 3450    9211  False    NaN      NaN   NaN
# 3451    9212  False    NaN      NaN   NaN
# 3452    9213  False    NaN      NaN   NaN
# 3453    9214  False    NaN      NaN   NaN
# 3454    9215  False    NaN      NaN   NaN
# 3455    9216  False    NaN      NaN   NaN
# 3456    9218  False    NaN      NaN   NaN
# 3457    9219  False    NaN      NaN   NaN
# 3458    9220  False    NaN      NaN   NaN
# 3459    9221  False    NaN      NaN   NaN
# 3460    9227  False    NaN      NaN   NaN
# 3461    9229  False    NaN      NaN   NaN
# 3462    9232  False    NaN      NaN   NaN
# 3463    9233  False    NaN      NaN   NaN
# 3464    9240  False    NaN      NaN   NaN
# 3465    9241  False    NaN      NaN   NaN
# 3466    9242  False    NaN      NaN   NaN
# 3467    9244  False    NaN      NaN   NaN
# 3468    9245  False    NaN      NaN   NaN
# 3469    9246  False    NaN      NaN   NaN
# 3470    9247  False    NaN      NaN   NaN
# 3471    9248  False    NaN      NaN   NaN
# 3472    9249  False    NaN      NaN   NaN
# 3473    9250  False    NaN      NaN   NaN
# 3474    9251  False    NaN      NaN   NaN
# 3475    9252  False    NaN      NaN   NaN
# 3476    9253  False    NaN      NaN   NaN
# 3477    9254  False    NaN      NaN   NaN
# 3478    9256  False    NaN      NaN   NaN
# 3479    9257  False    NaN      NaN   NaN
# 3480    9258  False    NaN      NaN   NaN
# 3481    9259  False    NaN      NaN   NaN
# 3482    9260  False    NaN      NaN   NaN
# 3483    9262  False    NaN      NaN   NaN
# 3484    9263  False    NaN      NaN   NaN
# 3485    9264  False    NaN      NaN   NaN
# 3486    9265  False    NaN      NaN   NaN
# 3487    9267  False    NaN      NaN   NaN
# 3488    9268  False    NaN      NaN   NaN
# 3489    9270  False    NaN      NaN   NaN
# 3490    9271  False    NaN      NaN   NaN
# 3491    9272  False    NaN      NaN   NaN
# 3492    9273  False    NaN      NaN   NaN
# 3493    9274  False    NaN      NaN   NaN
# 3494    9275  False    NaN      NaN   NaN
# 3495    9278  False    NaN      NaN   NaN
# 3496    9279  False    NaN      NaN   NaN
# 3497    9301  False    NaN      NaN   NaN
# 3498    9302  False    NaN      NaN   NaN
# 3499    9303  False    NaN      NaN   NaN
# 3500    9304  False    NaN      NaN   NaN
# 3501    9305  False    NaN      NaN   NaN
# 3502    9306  False    NaN      NaN   NaN
# 3503    9307  False    NaN      NaN   NaN
# 3504    9308  False    NaN      NaN   NaN
# 3505    9310  False    NaN      NaN   NaN
# 3506    9311  False    NaN      NaN   NaN
# 3507    9312  False    NaN      NaN   NaN
# 3508    9313  False    NaN      NaN   NaN
# 3509    9319  False    NaN      NaN   NaN
# 3510    9322  False    NaN      NaN   NaN
# 3511    9324  False    NaN      NaN   NaN
# 3512    9325  False    NaN      NaN   NaN
# 3513    9326  False    NaN      NaN   NaN
# 3514    9327  False    NaN      NaN   NaN
# 3515    9336  False    NaN      NaN   NaN
# 3516    9337  False    NaN      NaN   NaN
# 3517    9338  False    NaN      NaN   NaN
# 3518    9339  False    NaN      NaN   NaN
# 3519    9340  False    NaN      NaN   NaN
# 3520    9341  False    NaN      NaN   NaN
# 3521    9342  False    NaN      NaN   NaN
# 3522    9343  False    NaN      NaN   NaN
# 3523    9344  False    NaN      NaN   NaN
# 3524    9345  False    NaN      NaN   NaN
# 3525    9346  False    NaN      NaN   NaN
# 3526    9347  False    NaN      NaN   NaN
# 3527    9348   Done    NaN      NaN   NaN
# 3528    9351   Done    NaN      NaN   NaN
# 3529    9353   Done    NaN      NaN   NaN
# 3530    9355   Done    NaN      NaN   NaN
# 3531    9360   Done    NaN      NaN   NaN
# 3532    9361   Done   Done      NaN   NaN
# 3533    9362   Done   Done      NaN   NaN
# 3534    9363   Done   Done      NaN   NaN
# 3535    9364   Done  False      NaN   NaN
# 3536    9365   Done   Done      NaN   NaN
# 3537    9366   Done   Done      NaN   NaN
# 3538    9367   Done   Done      NaN   NaN
# 3539    9368   Done   Done      NaN   NaN
# 3540    9369   Done   Done      NaN   NaN
# 3541    9376   Done   Done      NaN   NaN
# 3542    9377   Done   Done      NaN   NaN
# 3543    9380   Done   Done      NaN   NaN
# 3544    9381   Done   Done      NaN   NaN
# 3545    9384   Done  False      NaN   NaN
# 3546    9385   Done  False      NaN   NaN
# 3547    9386   Done   Done      NaN   NaN
# 3548    9399   Done   Done      NaN   NaN
# 3549    9401   Done   Done      NaN   NaN
# 3550    9404   Done  False      NaN   NaN
# 3551    9405   Done   Done      NaN   NaN
# 3552    9408   Done   Done      NaN   NaN
# 3553    9409   Done   Done      NaN   NaN
# 3554    9412   Done  False      NaN   NaN
# 3555    9413   Done   Done      NaN   NaN
